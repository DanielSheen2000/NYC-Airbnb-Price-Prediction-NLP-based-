# %% [markdown]
# The task at hand is to predict Airbnb prices given certain metrics in NYC.
#
# **NOTE**: This project is done solely for personal practice. Please let me know where I can improve on or if there are any questions to my thinking. Thank you!

# %%
#from pandas import read_csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pandas.plotting import scatter_matrix
from matplotlib import pyplot

# %% [markdown]
# <h3> Obtaining Data

# %%
df = pd.read_csv('AB_NYC_2019.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
columns = df.columns
columns, len(columns)
# Out:
# (Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#         'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#         'minimum_nights', 'number_of_reviews', 'last_review',
#         'reviews_per_month', 'calculated_host_listings_count',
#         'availability_365'],
#        dtype='object'),
#  16)

# %% [markdown]
# <h3> Exploring Data

# %%
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# We have 16 total features and ~49000 samples. Not all of the features are useful and we are also unsure if all samples are valid (i.e. presence of NaN) so we will most likely have to perform feature engineering to obtain more useful data. Let's see if we can get any insights from the data before making any changes to it. <br>
#
# Note that majority of the features are self-explanatory, but just for clarification:
# 1. **'calculated_host_listings_count'** indicates the total number of apartments and bedrooms referred to the same landlord (one landlord can have more than one property in NY) [1]
# 2. **'availability_365'** indicates the # of days in an year that the airbnb is available. It is possible for this value to be 0 [2]
#
# [1]https://www.kaggle.com/dgomonov/new-york-city-airbnb-open-data/discussion/120300 <br>
# [2]https://www.kaggle.com/dgomonov/new-york-city-airbnb-open-data/discussion/111835

# %%
# checking data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %%
# checking # of NaN in each column
if(df.isnull().values.any() == True):
    for name in columns:
        print('%s: %i' %(name, df[name].isnull().sum()) )
# Out:
# id: 0
# name: 16
# host_id: 0
# host_name: 21
# neighbourhood_group: 0
# neighbourhood: 0
# latitude: 0
# longitude: 0
# room_type: 0
# price: 0
# minimum_nights: 0
# number_of_reviews: 0
# last_review: 10052
# reviews_per_month: 10052
# calculated_host_listings_count: 0
# availability_365: 0

# %% [markdown]
# Majority of the NaN are in the last_review and reviews_per_month feature. This makes sense because last_review is a date type and some error most likely occured during the data gathering portion. reviews_per_month are NaN because of a division by 0 error.
#
# As of now, we can drop a couple of columns that (in my honest opinion) are not that important:
# 1. id
# 2. host_id
# 3. host_name
# 4. last_review

# %%
df.drop(columns = ['id', 'host_id', 'host_name', 'last_review'], inplace = True)
df.head()
# Out:
#                                                name neighbourhood_group  \
# 0                Clean & quiet apt home by the park            Brooklyn
# 1                             Skylit Midtown Castle           Manhattan
# 2               THE VILLAGE OF HARLEM....NEW YORK !           Manhattan
# 3                   Cozy Entire Floor of Brownstone            Brooklyn
# 4  Entire Apt: Spacious Studio/Loft by central park           Manhattan
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0    Kensington  40.64749  -73.97237     Private room    149               1
# 1       Midtown  40.75362  -73.98377  Entire home/apt    225               1
# 2        Harlem  40.80902  -73.94190     Private room    150               3
# 3  Clinton Hill  40.68514  -73.95976  Entire home/apt     89               1
# 4   East Harlem  40.79851  -73.94399  Entire home/apt     80              10
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  9               0.21                               6
# 1                 45               0.38                               2
# 2                  0                NaN                               1
# 3                270               4.64                               1
# 4                  9               0.10                               1
#
#    availability_365
# 0               365
# 1               355
# 2               365
# 3               194
# 4                 0

# %% [markdown]
# We left some columns over that might potentially be useful. If not, we will simply drop them later. First, let's deal with the NaN and potentially invalid data.
#
# As mentioned earlier, availability_365 can equal 0, meaning that the owner is never open for an year. It is unknown whether the host is just closed or if it's bad data, but we will remove samples where availability_365 = 0. There are no NaN values in this column so we won't need to handle that case.

# %%
df_1 = df[df['availability_365'] > 0]
df_1
# Out:
#                                                     name neighbourhood_group  \
# 0                     Clean & quiet apt home by the park            Brooklyn
# 1                                  Skylit Midtown Castle           Manhattan
# 2                    THE VILLAGE OF HARLEM....NEW YORK !           Manhattan
# 3                        Cozy Entire Floor of Brownstone            Brooklyn
# 5              Large Cozy 1 BR Apartment In Midtown East           Manhattan
# ...                                                  ...                 ...
# 48890    Charming one bedroom - newly renovated rowhouse            Brooklyn
# 48891      Affordable room in Bushwick/East Williamsburg            Brooklyn
# 48892            Sunny Studio at Historical Neighborhood           Manhattan
# 48893               43rd St. Time Square-cozy single bed           Manhattan
# 48894  Trendy duplex in the very heart of Hell's Kitchen           Manhattan
#
#             neighbourhood  latitude  longitude        room_type  price  \
# 0              Kensington  40.64749  -73.97237     Private room    149
# 1                 Midtown  40.75362  -73.98377  Entire home/apt    225
# 2                  Harlem  40.80902  -73.94190     Private room    150
# 3            Clinton Hill  40.68514  -73.95976  Entire home/apt     89
# 5             Murray Hill  40.74767  -73.97500  Entire home/apt    200
# ...                   ...       ...        ...              ...    ...
# 48890  Bedford-Stuyvesant  40.67853  -73.94995     Private room     70
# 48891            Bushwick  40.70184  -73.93317     Private room     40
# 48892              Harlem  40.81475  -73.94867  Entire home/apt    115
# 48893      Hell's Kitchen  40.75751  -73.99112      Shared room     55
# 48894      Hell's Kitchen  40.76404  -73.98933     Private room     90
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 0                   1                  9               0.21
# 1                   1                 45               0.38
# 2                   3                  0                NaN
# 3                   1                270               4.64
# 5                   3                 74               0.59
# ...               ...                ...                ...
# 48890               2                  0                NaN
# 48891               4                  0                NaN
# 48892              10                  0                NaN
# 48893               1                  0                NaN
# 48894               7                  0                NaN
#
#        calculated_host_listings_count  availability_365
# 0                                   6               365
# 1                                   2               355
# 2                                   1               365
# 3                                   1               194
# 5                                   1               129
# ...                               ...               ...
# 48890                               2                 9
# 48891                               2                36
# 48892                               1                27
# 48893                               6                 2
# 48894                               1                23
#
# [31362 rows x 12 columns]

# %% [markdown]
# **NOTE**: ~17000 samples were removed

# %% [markdown]
# Now changing NaN values in the reviews_per_month into 0

# %%
df_1['reviews_per_month'] = df['reviews_per_month'].fillna(0)
df_1
# Out:
# C:\Users\Daniel\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                                     name neighbourhood_group  \
# 0                     Clean & quiet apt home by the park            Brooklyn
# 1                                  Skylit Midtown Castle           Manhattan
# 2                    THE VILLAGE OF HARLEM....NEW YORK !           Manhattan
# 3                        Cozy Entire Floor of Brownstone            Brooklyn
# 5              Large Cozy 1 BR Apartment In Midtown East           Manhattan
# ...                                                  ...                 ...
# 48890    Charming one bedroom - newly renovated rowhouse            Brooklyn
# 48891      Affordable room in Bushwick/East Williamsburg            Brooklyn
# 48892            Sunny Studio at Historical Neighborhood           Manhattan
# 48893               43rd St. Time Square-cozy single bed           Manhattan
# 48894  Trendy duplex in the very heart of Hell's Kitchen           Manhattan
#
#             neighbourhood  latitude  longitude        room_type  price  \
# 0              Kensington  40.64749  -73.97237     Private room    149
# 1                 Midtown  40.75362  -73.98377  Entire home/apt    225
# 2                  Harlem  40.80902  -73.94190     Private room    150
# 3            Clinton Hill  40.68514  -73.95976  Entire home/apt     89
# 5             Murray Hill  40.74767  -73.97500  Entire home/apt    200
# ...                   ...       ...        ...              ...    ...
# 48890  Bedford-Stuyvesant  40.67853  -73.94995     Private room     70
# 48891            Bushwick  40.70184  -73.93317     Private room     40
# 48892              Harlem  40.81475  -73.94867  Entire home/apt    115
# 48893      Hell's Kitchen  40.75751  -73.99112      Shared room     55
# 48894      Hell's Kitchen  40.76404  -73.98933     Private room     90
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 0                   1                  9               0.21
# 1                   1                 45               0.38
# 2                   3                  0               0.00
# 3                   1                270               4.64
# 5                   3                 74               0.59
# ...               ...                ...                ...
# 48890               2                  0               0.00
# 48891               4                  0               0.00
# 48892              10                  0               0.00
# 48893               1                  0               0.00
# 48894               7                  0               0.00
#
#        calculated_host_listings_count  availability_365
# 0                                   6               365
# 1                                   2               355
# 2                                   1               365
# 3                                   1               194
# 5                                   1               129
# ...                               ...               ...
# 48890                               2                 9
# 48891                               2                36
# 48892                               1                27
# 48893                               6                 2
# 48894                               1                23
#
# [31362 rows x 12 columns]

# %% [markdown]
# We had 4 NaN values in the name category as well. We will simply fill these with blanks (i.e. '')

# %%
df = df_1.copy()
df['name'] = df_1['name'].fillna('to') # we are using 'to' bc it is a stopword -> explained later

# %%
# checking our NaN values again
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# As of this moment, I have no idea how to incorporate latitude and longitude into my model. I think it's a fair assumption to make that latitude and longitude are not normal metrics used when people are considering prices n such. In addition, these two columns are essentially incorporated in the neighbourhood_group and neighbourhood columns.

# %%
df.drop(columns = ['latitude', 'longitude'], inplace = True)
df.head()
# Out:
#                                         name neighbourhood_group  \
# 0         Clean & quiet apt home by the park            Brooklyn
# 1                      Skylit Midtown Castle           Manhattan
# 2        THE VILLAGE OF HARLEM....NEW YORK !           Manhattan
# 3            Cozy Entire Floor of Brownstone            Brooklyn
# 5  Large Cozy 1 BR Apartment In Midtown East           Manhattan
#
#   neighbourhood        room_type  price  minimum_nights  number_of_reviews  \
# 0    Kensington     Private room    149               1                  9
# 1       Midtown  Entire home/apt    225               1                 45
# 2        Harlem     Private room    150               3                  0
# 3  Clinton Hill  Entire home/apt     89               1                270
# 5   Murray Hill  Entire home/apt    200               3                 74
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2               0.00                               1               365
# 3               4.64                               1               194
# 5               0.59                               1               129

# %% [markdown]
# <h3> Encoding + Feature Engineering

# %% [markdown]
# We will not be able to use string types in our model, so we will have to encode room_type, neighbourhood_group and neighbourhood.
#
# In addition, the name that the airbnb is titled is (once again in my opinion) an important factor that people consider when going through AirBnb's (no one wants to rent an airbnb called craphole). So we will perform natural language processing on this column and perform sentiment analysis to obtain some kind of score. Note that there are several flaws with this plan such as the fact that there is no dictionary available to map terms specific for real estate and property to a value. Also, given how small the strings are in the name column (character wise), there might be large variance in sentiment values.

# %% [markdown]
# <h4> Encoding

# %%
df['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df['neighbourhood'].unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'Murray Hill',
#        "Hell's Kitchen", 'Chinatown', 'Upper West Side', 'South Slope',
#        'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#        'East Harlem', 'Park Slope', 'Bedford-Stuyvesant',
#        'Windsor Terrace', 'Inwood', 'East Village', 'Greenpoint',
#        'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'West Village', 'Gowanus', 'Flatlands',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Ridgewood', 'Morningside Heights', 'Jamaica',
#        'Middle Village', 'NoHo', 'Ditmars Steinway', 'Cobble Hill',
#        'Flatiron District', 'Roosevelt Island', 'Greenwich Village',
#        'East Flatbush', 'Tompkinsville', 'Astoria', 'Clason Point',
#        'Eastchester', 'Little Italy', 'Kingsbridge', 'Two Bridges',
#        'Queens Village', 'Rockaway Beach', 'Forest Hills', 'Nolita',
#        'Woodlawn', 'University Heights', 'Gramercy', 'Allerton',
#        'East New York', 'Theater District', 'Concourse Village',
#        'Sheepshead Bay', 'Emerson Hill', 'Fort Hamilton', 'Bensonhurst',
#        'Tribeca', 'Shore Acres', 'Concourse', 'Elmhurst', 'Sunset Park',
#        'Brighton Beach', 'Jackson Heights', 'Cypress Hills', 'Arrochar',
#        'Financial District', 'Wakefield', 'Clifton', 'Bay Ridge',
#        'Graniteville', 'Spuyten Duyvil', 'Stapleton', 'Ozone Park',
#        'Columbia St', 'Briarwood', 'Mott Haven', 'Longwood', 'Canarsie',
#        'Civic Center', 'East Elmhurst', 'New Springville',
#        'Morris Heights', 'Rego Park', 'Arverne', 'Gravesend',
#        'Cambria Heights', 'Tottenville', 'Mariners Harbor', 'Concord',
#        'Borough Park', 'Bayside', 'Downtown Brooklyn', 'Port Morris',
#        'Fieldston', 'Kew Gardens', 'Midwood', 'College Point',
#        'Mount Eden', 'Glendale', 'Red Hook', 'Richmond Hill', 'Bellerose',
#        'St. Albans', 'Maspeth', 'Battery Park City', 'Williamsbridge',
#        'Soundview', 'Woodhaven', 'Co-op City', 'City Island',
#        'North Riverdale', 'Dyker Heights', 'Sea Gate', 'Riverdale',
#        'Kew Gardens Hills', 'Bay Terrace', 'Norwood', 'Claremont Village',
#        'Whitestone', 'Fordham', 'Bayswater', 'Navy Yard', 'Brownsville',
#        'Vinegar Hill', 'Eltingville', 'Fresh Meadows', 'Mount Hope',
#        'Lighthouse Hill', 'Springfield Gardens', 'Howard Beach',
#        'Belle Harbor', 'Jamaica Estates', 'Van Nest', 'West Brighton',
#        'Far Rockaway', 'South Ozone Park', 'Corona', 'Great Kills',
#        'Manhattan Beach', 'Castleton Corners', 'Stuyvesant Town',
#        'East Morrisania', 'Hunts Point', 'Neponsit', 'Pelham Bay',
#        'Randall Manor', 'Throgs Neck', 'West Farms', 'Silver Lake',
#        'Laurelton', 'Holliswood', 'Pelham Gardens', 'Parkchester',
#        'Rosedale', 'Edgemere', 'New Brighton', 'Baychester', 'Bronxdale',
#        'Marble Hill', 'Melrose', 'Bergen Beach', 'Richmondtown',
#        'Tremont', 'Howland Hook', 'Schuylerville', 'Coney Island',
#        'South Beach', 'Bath Beach', 'Midland Beach', 'Oakwood',
#        'Castle Hill', 'Hollis', 'Morris Park', 'Douglaston', 'Huguenot',
#        'Edenwald', 'Dongan Hills', 'Grant City', 'Port Richmond',
#        'Westerleigh', 'Morrisania', 'Westchester Square', 'Little Neck',
#        'Fort Wadsworth', 'Rosebank', 'Unionport', 'Mill Basin', 'Belmont',
#        'Arden Heights', 'Olinville', 'Grymes Hill', 'Rossville',
#        'Breezy Point', "Prince's Bay", 'Willowbrook', 'New Dorp Beach',
#        "Bull's Head", 'Todt Hill', 'Jamaica Hills'], dtype=object)

# %% [markdown]
# There are no copied values or invalid values (from a glance) so we will not have to perform any cleaning

# %%
# taking columns with an object type only
object_cols = df.select_dtypes(include = [object])

# dropping the name column bc we do not want to perform encoding on it
object_cols.drop(columns = ['name'], inplace = True)
object_cols.head()
# Out:
# C:\Users\Daniel\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#   neighbourhood_group neighbourhood        room_type
# 0            Brooklyn    Kensington     Private room
# 1           Manhattan       Midtown  Entire home/apt
# 2           Manhattan        Harlem     Private room
# 3            Brooklyn  Clinton Hill  Entire home/apt
# 5           Manhattan   Murray Hill  Entire home/apt

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
object_cols = encoder.fit_transform(object_cols)

# %% [markdown]
# <h4> Sentiment Analysis

# %% [markdown]
# Now we will perform sentiment analysis on the name column. Remember that we added 'to' to the NaN in the name column.  VADER will be our chosen library for sentiment analysis. It is capable of picking up on use of capitalization, slangs and emjois to some extent, making it more accurate for informal writings such as this.

# %%
# creating a function to remove stop words to decrease our runtime
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
def stop_words(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    filtered_sentence = [w for w in word_tokens if not w in stop_words]
    return filtered_sentence

# %% [markdown]
# Now let's go through our name column one last time. Since our sentiment analysis will only be applied to english, we should check to see if all the titles are in english. We will be using langdetect for this.

# %%
from langdetect import detect
from langdetect.lang_detect_exception import LangDetectException

description = df['name'].astype(str)

errors = []
not_english = []
english = 0
other = 0
for title in description:
    try:
        #print(title)
        if detect(title) == 'en':
            english += 1
        else:
            not_english += [title]
            other += 1
    except LangDetectException:
        other += 1
        errors += [title]
english, other
# Out:
# (26299, 5063)

# %% [markdown]
# Not all of the descriptions of the airbnbs get detected as english even though they are in english, which might create problems for our sentiment analysis. This issue is most likely caused by langdetect having too many languages it is capable of detecting. Couple other factors is that people use slangs, emojis and mix languages together, making it a difficult task to pinpoint the exact language.

# %%
not_english
# Out:
# ['THE VILLAGE OF HARLEM....NEW YORK !',
#  'CBG Helps Haiti Room#2.5',
#  'SPACIOUS, LOVELY FURNISHED MANHATTAN BEDROOM',
#  'Modern 1 BR / NYC / EAST VILLAGE',
#  'back room/bunk beds',
#  'Large B&B Style rooms',
#  'West Side Retreat',
#  'BEST BET IN HARLEM',
#  '* ORIGINAL BROOKLYN LOFT *',
#  'Williamsburg 1 bedroom Apartment',
#  'Room in Greenpoint Loft w/ Roof',
#  '2 bedroom - Upper East Side-great for kids',
#  'BLUE TRIM GUEST HOUSE',
#  'Manhattan Room',
#  'Entire 2 Bedroom - Large & Sunny',
#  '2 bedroom Williamsburg Apt - Bedford L stop',
#  'Cozy Bedroom in Williamsburg 3 BR',
#  'COZY QUIET room 4 DOOGLERS!',
#  'House On Henry (3rd FLR Suite)',
#  'Beautiful Duplex Apartment',
#  'Beautiful Apartment East Village',
#  'Sugar Hill Rest Stop ',
#  'ACCOMMODATIONS GALORE #1',
#  'Unique & Charming small 1br Apt. LES',
#  'Luminous Beautiful West Village Studio',
#  'Modern Greenpoint, Brooklyn Apt',
#  'FLAT MACDONOUGH GARDEN',
#  'NYC Zen',
#  'Cozy BR in Wiliamsburg 3 Bedroom',
#  'West Inn 2 - East Village',
#  'BROOKLYN VICTORIAN STYLE SUITE.....',
#  'ACCOMMODATIONS GALORE#3. 1-5 GUESTS',
#  'Park Slope haven 15 mins from Soho',
#  '( F) Excellent/Pvt Rm',
#  'MIDTOWN WEST - Large alcove studio',
#  'Sml Rm in pr Brst  Park Sl great for Med/students',
#  'Cozy bedroom by Yankee Stadium',
#  'NOHO/EAST VILLAGE, PRIVATE 1/2 BATH',
#  'Elegant NYC Pad',
#  'Nice, clean, safe, convenient 3BR',
#  'Franklin St Flat in Trendy Greenpoint Brooklyn',
#  'ACCOMMODATIONS GALORE #2',
#  'BK Sweet Suite w/Kitchen&FullBath',
#  'BROWNSTONE SUNDRENCHED BEAUTY',
#  'LL3',
#  'HOSTING YOUR  SUNNY, SPACIOUS NYC ROOM',
#  'BROOKLYN  STUDIO APARTMENT',
#  'Beautiful 1 Bedroom Apt Park Slope',
#  'Cozy Garden Apartment  in Williamsburg',
#  "Brooklyn Writer's Nook",
#  'One Bedroom Mini studio - Free WIFI',
#  'Hells Kitchen Garden of Eden',
#  'Columbia Castle 2 BR',
#  'Ft. Greene garden gem, large and convenient',
#  'MODERN SPACIOUS 2 BR APT DOWNTOWN MANHATTAN',
#  'MAISON DES SIRENES 2',
#  'LARGE 1BR (CONV 2BR) CROWN HEIGHTS',
#  'Sunny Bklyn Jewel  Fort Greene JULY  - AUG 2019',
#  'Bienvenue',
#  'BOHEMIAN EAST VILLAGE 2 BED HAVEN',
#  'Sun-Drenched Hamilton Hts Jewel   ',
#  '1 BDRM Apt-Weekend Sublease',
#  'ROOM WITH A  KITCHENETTE',
#  "⚡Quiet Gem w/roof deck on NY's Hottest Street⚡",
#  'SUPER BIG AND COZY PRIVATE BEDROOM',
#  'LUXURY OF THE HORIZON',
#  'Beautiful Duplex w/Private Garden',
#  'Garage Designer Loft',
#  'CHARMING PRIVATE BEDROOM EAST VILLAGE',
#  'Sunny 15min to Manhattan LADY only',
#  'CBG# 4Tiny room w/ huge window/AC',
#  'Sunny, quiet, legal homelike suite-Pk Slope South',
#  'Fort Greene, Brooklyn: Front Bedroom',
#  'spacious studio',
#  'Elegant 2-BR duplex, Union Square',
#  'SPACIOUS ALCOVE STUDIO/ JUNIOR ONE',
#  'Ultra Modern NYC Garden Apartment',
#  'Modern Garden Apartment in NYC',
#  'WEST VILLAGE LRG CLEAN SUNNY PRIVATE BDRM',
#  'Large, sunny garden apartment.',
#  'Beautiful Grdn. Apt. in Park Slope',
#  'Large Room Overlooking Central Park',
#  '2 Beds over Bed-Stuy',
#  'Sunny, Large, Park Slope Bedroom',
#  'Large room in elevator drman bldg',
#  'Modern Bedroom in Hamilton Heights',
#  'STYLISH EAST VILLAGE FLAT',
#  'Serene Park Slope Garden Apartment',
#  'Modern Unique Studio in NYC',
#  '✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿',
#  '✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿',
#  'CBG Helps Haiti Rm #3',
#  'Artsy Loft-like Harlem Apartment',
#  'Sunny 2 bedroom Williamsburg Duplex w/ 3 beds',
#  'ROOM WITH KITCHENETTE #2',
#  'Zen Yankee Stadium Pad 5 Minutes To Manhattan!',
#  'LES private apt, 1 bedroom & more',
#  "LOCATION LOCATION LOCATION Liz's",
#  'Astoria Garden Suite',
#  'Amazing 1 bed, live like a Newyorkr',
#  'Private Room Near Brooklyn Museum ',
#  'One Fabulous Private Room',
#  'HANCOCK VERY SMALL ROOM',
#  'NOLITA! LOCATION! LOCATION! VIEWS! FREE GYM!',
#  'Zen Den (Airport Pickup: JFK & LGA)',
#  'Landmark 2 Bedroom West Village NYC',
#  'Bright unique designer loft in Soho',
#  'SUNNY 1 Bedroom APT in Fort Greene - BROOKLYN',
#  'Brooklyn: A Huge Bedroom + Good Vibes',
#  'BEDFORD AV.  ROOM IN WILLIAMSBURG..',
#  'Sleep & Wake near Botanical Gardens',
#  'Comfortable Manhattanville.',
#  "Beautiful lrg 1800's syle apt share",
#  'Kensington/Ditmas Park pied-a-terre',
#  'Park Slope Brooklyn!  Sunny Bedroom.',
#  'Cozy, beautiful doormen studio-',
#  'Zen Minimalist w/Garden- Bedford L Stop',
#  'BIG LUXURY LINCOLN CENTER AREA STUDIO + !!',
#  'Brooklyn Beauty - Large 2 bedroom Apartment',
#  'Gorgeous pvt room in West Village',
#  '1 bedroom apt in Midtown West',
#  'Private room in 2 br Apt, Wburg, BK',
#  'Feel like you never leave your home',
#  '2 BD / 2BA WITH GARDEN, SLEEPS 6',
#  '2ND AVENUE OFF HOUSTON/LOFTLIKE STU',
#  'Room in Huge 1200sf W Harlem Suite',
#  'Peaceful Room...',
#  'Large Master Bedroom - Williamsburg',
#  'HOSTING YOUR COZY,  ECLECTIC MILIEU FOR NYC VISIT',
#  'Queen size sofa bed in Harlem',
#  'TIMES SQUARE HOUSE!',
#  'ARTY 2 BED EAST VILLAGE GEM',
#  'Lower East Side 1bedroom apt in NYC',
#  'Large Beautiful East Village 1-Bdrm',
#  'Den of Zen at The Denizen Bushwick',
#  'ingefära hus! Private room Williamsburg, Brooklyn',
#  'LUXURY 2BD/2BTH - HUGE PATIO',
#  'A PLACE TO STAY CLOSE TO MANHATTAN',
#  "THERE'S NO PLACE LIKE HOME.........",
#  'Single Room',
#  'PARK SLOPE: SWEET, LARGE 2BR DUPLEX',
#  'Sunny UES 1.5 Bedroom, Sleeps 6',
#  'LUXE Privé L.I.C. Apt & Garden',
#  'Beautiful Room + Private Balcony',
#  'All Charm: Lush Garden, Huge Kitchen + Quiet',
#  'SUNNY ZEN  FULL SERVICE HUGE STUDIO',
#  'Room in Harlem',
#  'Big Beautiful Brooklyn Apt @ Park!',
#  'comfy room minutes from museums',
#  'Lavender Joy Room in Duplex!',
#  'Serene Room...',
#  'UNION SQUARE❤️PENTHOUSE 2FL+TERRACE❤️EAST VIllAGE',
#  'West Village Loft, 1st floor',
#  'yahmanscrashpads',
#  'Our NY home, Greenwich Village apt',
#  'Cozy place',
#  'Mini Loft Williamsburg Bkln-Bedford',
#  'GREAT BRAND NEW 1 BED APT*TIMES SQ',
#  'Loft-Like Park Slope 3bdr Duplex',
#  'PRIME LOCATION STYLISH COMFORT',
#  'Private Bedroom in Wooden House',
#  'Bronx Room Near Yankees + Harlem',
#  "Artist's Ditmas Pk 5 bedroom house",
#  'Boerum Hill Brownstone Garden Duplx',
#  'Yankee Nest',
#  '1 BR Village - 30 day+ stay',
#  'Upper West Side 1-bedroom',
#  'QUITE LOVELY STUDIO IN HEART OF HELLS KITCHEN**',
#  'Brooklyn Summer Sublet-Ditmas Park',
#  'Feels like home with park view',
#  'Bedroom, kitchen and private garden',
#  'Gorgeous Unique Garden-Terrace-Apt.',
#  'GREAT DEAL IN TIMES SQ./HK',
#  'GREAT EAST VILLAGE LOCATION, ELEVATOR & ROOFTOP!!!',
#  '☆ 2BR East Village ☆ Sleeps 5 | BEST LOCATION ☆',
#  'large spacious room',
#  'Central Park West/ 80s One bedroom!',
#  "PRIVATE ROOM in HELL'S KITCHEN, NYC",
#  'SOHO/VILLAGE CHARMING STUDIO',
#  'LARGE BEDROOM +PRIVATE BATHROOM',
#  'Beautiful Bedroom in Brooklyn',
#  'Greenwich Village Skylit 1BR +deck!',
#  '1 Bed Manhattan Apt. Minimum 7 DAYS',
#  'Sml Rm in pr. Brst in Pk Sl great for Med/students',
#  'Amazing Greenpoint/WBurg, BRKLN 1BR',
#  'Cosy Large Bedroom Park Slope',
#  'Convenient, Central, Comfortable',
#  '1 FLOOR OF A BROWNSTONE WITH GARDEN',
#  'Cozy bedroom in Hells Kitchen',
#  'ENTIRE LUXURY MADISON AVE STUDIO',
#  "Sal's bnb",
#  'Jacuzzi Suite, Minutes to Times Sq.',
#  'Cozy E. Harlem Brownstone PH',
#  'Charming 1 bedroom Apt in Brooklyn',
#  'Comfortable, clean & quiet in EV',
#  'ELEGANT MIDTOWN EAST STUDIO E.52 ST',
#  "Be in NYC's best: Lower East Side!",
#  'QUIET, SPACIOUS, COMFORTABLE, & GREAT LOCATION',
#  'Secret Garden',
#  'HEART OF NYC! Sunny furn 1 br wifi',
#  'BEDFORD AVE STUDIO APT WITH GARDEN',
#  'Amazing Williamsburg entire Loft. Floor 2B',
#  'My Brooklyn Studio in Ditmas Park',
#  'Bookcase Room with Hidden Door!',
#  'REDUCED! Private Apt~Fun NYC area!',
#  'Secret Garden Big and Comfortable',
#  'A LITTLE PARADISE NEXT TO SUBWAY!',
#  '(B)  BARGAIN SPACE',
#  'NEAR THE CITY THAT NEVER SLEEPS!',
#  'Beautiful West Village 1 BR apartment',
#  'Huge Sunny Modern Apt. (1k+sqft)',
#  "Brooklyn's top",
#  'LARGE PRIVATE FLOOR IN BROOKLYN, NY',
#  'Comfy apartment, adorable cat!',
#  'SUNNY LOFT: Greenwich Village, NYC',
#  'Classy Brooklyn Studio',
#  'HISTORIC WILLIAMSBURG, BKLYN #2',
#  'Brand New 2-Level 2-Bedroom Condo',
#  'West Village 2 Bedroom Apt',
#  'Bright 1 BR in Brooklyn',
#  'Grand Brooklyn Apartment',
#  'AMAZING COLUMBUS CIRCLE LOCATION :)',
#  'Private Bedroom in Sunny Brooklyn Apartment',
#  'Williamsburg Loft!! Bedford L 1blk!',
#  'BEST KIPS BAY LOCATION. HUGE 1BD',
#  'Upper West Side Stunner',
#  '1 Private Bedroom / East Village',
#  'Super Cute Upper West Side Apt!!',
#  'Location Moreno',
#  'PRIVATE BATH/TONS OF SUNLIGHT/SAFE',
#  'UES Manhattan Quiet Nest 1 Bdrm',
#  'Private Oasis, en suite bathroom',
#  "Art Lover's Abode Brooklyn",
#  'Great spot in Brooklyn',
#  'Gorgeous Brooklyn Getaway',
#  'Large 2 bedroom, full floor apt.',
#  'Private Bedroom LOWER EAST SIDE',
#  'GREAT ROOM Fast 2 TIMES SQ 9min NYC',
#  'PRIVATE ROOFTOP +BEST LOCATION+COZY',
#  'Lincoln Center  luxury condo',
#  'Brooklyn two bedroom',
#  'Brooklyn Oasis - Master Bedroom.',
#  'Modern 1-bedroom in Harlem Heights',
#  'CBG HelpsHaiti #5 Suite',
#  'Home Sweet Room-SAPPHIRE-Queens NYC',
#  'Home Sweet Room-EMERALD-Queens NYC!',
#  'Great Space / Private Room',
#  "DEBBIE'S COZY RETREAT",
#  'MANHATTAN BEAUTIFUL PIANO ROOM',
#  'Near Manhatten, NEW Empire Outlets, park!',
#  'Experience Brooklyn like a True Brooklynite',
#  "Cute Room in Artist/Designers' Flat",
#  'DESIGNER LOFT W PRIVATE ROOFTOP & PANORAMIC VIEWS',
#  'Manhattan Lux Loft.Like.Love.Lots.Look !',
#  'Brooklyn Apt: 1 Bedroom w/Garden',
#  'Awesome, Unique EAST VILLAGE LOFT!!',
#  'Amazing Greenwich Village w pool',
#  'XL 90m2 2BR Victorian area,sleeps 7',
#  'Modern condo close to Prospect park',
#  'LUXURY APT w PRIVATE GARDEN NYC UES',
#  'Upper Manhattan//Harlem Classic',
#  'Cute Studio Greenwich Village NYC',
#  'ARTIST TRENDY NYC LOFT',
#  'Gowanis Urban Oasis',
#  'Large Room in Garden Duplex  ',
#  'PEACEFUL SHARE BY CENTRAL PARK',
#  '3 Bedroom Upper West Side Gem',
#  'Private Suite, Free Metrocard*',
#  'Large 2 bedroom apt in Manhattan',
#  'Hip Modern West Village Apartment',
#  'Brooklyn-Bedstuy-Studio',
#  'PAINTERS PARADISE / GREENPOINT',
#  'Central Pk West-Convenient 1 BR',
#  'Avenue A Apartment',
#  'Garden Apartment in Park Slope',
#  'Park Slope LARGEST (private) SHARE IN PARK SLOPE',
#  '2 Bedroom Apt in Caroll Gardens',
#  'Sunny, private room in Brooklyn!',
#  'Fort Greene Jewel',
#  "HELL'S KITCHEN STUDIO for 2 or 3",
#  'Beautiful 1BR in Prime West Village',
#  'West Village Large 1BR',
#  '*Sunny Master BD* in Garden Duplex',
#  'Large bedroom/Heart of Brooklyn',
#  'WATER VIEWS 3 BED HOME W/ PARKING',
#  'Private room in large 2 bed room',
#  'Cozy private room in 2 Bedroom, BK',
#  'Garden Apt, 5 mins from LaGuardia',
#  'Upper West Side Pied A Terre /NYC',
#  "Quiet ST MARK'S PLACE ARTIST'S GEM",
#  'Beautiful, private, uptown studio',
#  'QUIET GARDEN APT FACING NY BAY!',
#  'Village Life, 2-Bedroom, East Village',
#  'BIG & SUNNY, 1 STOP FROM MANHATTAN',
#  'Upper West Side Amazing Large 2 Bedrooms',
#  'Large 2 BDRM @ McCarren Park!!',
#  'Cute Bedroom in Clinton Hill',
#  'PRIVATE QUIET SUITE',
#  'Mi Casa Tu Casa Guesthouse Mexico ',
#  'BIG, COMFY, 4BR DUPLEX, GARDEN APT, Williamsburg',
#  'HELLO HARLEM',
#  'Dear Potential Airbnb Guests.',
#  'HISTORIC WILLIAMSBURG, BKLYN',
#  '“L l,x w w.     XThank &mftkn.  .',
#  'Sunny Sunset Park Artist Loft',
#  'Bright, Huge Room in 3 Bedroom Apt.',
#  'You take living or bedroom!',
#  'Private Room in Large Apt w/ Gorgeous Park View',
#  'Stunner Garden Apt in Townhouse',
#  'THE PUTNAM',
#  'Beautiful Park Slope 3bdrm Duplex',
#  'Forget NYC, Stay in Williamsburg! Best 1 BR Apt',
#  'ART HOUSE VAULT',
#  'Andy Phillips',
#  'Private Home w/ Parking in Brooklyn',
#  'spacious PARK SLOPE room available ',
#  'Unique 1BR in energetic E. Village',
#  '1 BDR in Greenwich Village Full APT',
#  'Private room/bedroom in Park Slope/Gowanus BK',
#  'Large Flatiron 2 bedroom',
#  '5 STARS***MIDTOWN EAST-BRAND NEW!!!',
#  'RUSTIC/MODERN/EV/NYC',
#  'Bright room in Brooklyn',
#  'MODERN/ SUBWAY/TERRACE/LOFT/ LARGE MASTER BEDROOM',
#  'Entire 2 bedroom flat',
#  'Huge Private Sunny Bedroom in NYC',
#  'Beautiful, clean 1-bdrm private apt',
#  'spacious, tranquil east village apt',
#  'Hostess Dawn in Brooklyn.',
#  'Sunlit cozy studio apt in UWS (70s)',
#  'Large 1 Bedroom in Astoria',
#  'STUNNING OCEAN-VIEW 1BR in BROOKLYN, NYC',
#  'Cozy 1 Bedroom in Clinton Hill',
#  '1 room available for rent in 3 bedroom.',
#  'Quiet minimal clean',
#  'Private bedroom (15 min Manhattan).',
#  'Modern Williamsburg',
#  'Manhattan Upper East Side 1bedroom',
#  'Beautiful Park Slope apt w garden',
#  'Designer amazing room in NYC!!',
#  'nice room in bedstuy N',
#  'BEAUTIFUL UPPER WEST SIDE SANCTUARY',
#  'nice room in bedstuy I',
#  'ABSOLUTELY GORGEOUS $10MILLION LOFT w/BASQUIAT',
#  'nice room in bedstuy H',
#  '1BR LUXURY PENTHOUSE MODERN CONDO',
#  'Dream Apartment - Greenwich Village',
#  'nice room in bedstuy M',
#  'True West Village Experience-1 Bdrm',
#  'Superstar Manhattan Apt - Harlem',
#  'PROSPECT HEIGHTS LARGE PRIVATE ROOM',
#  "BROWNSTONE BROOKLYN'S FINEST in NYC",
#  'GORGEOUS SUNNY LOFT w/ 15 WINDOWS',
#  'nice room in bedstuy K',
#  'Sunny, Huge, Quiet Room Doorman Bld',
#  'Doorman Bldg, Sunny, Huge, Quiet Rm',
#  'Garden duplx in beautiful brwnstne',
#  'Sunny Private Room in Brooklyn ',
#  'Sunny master bedroom Room in LowerEastSide/Nolita',
#  'Garden, Private Deck, Williamsburg apartment',
#  'nice room in bedstuy J',
#  'Beautiful Central Harlem sleeps 4',
#  'Sweet Deal*Harlem2bdrm Apt #1/Sleeps4',
#  'MIDTOWN EAST 1BR APARTMENT - NEW',
#  'LUXMaster Suite 24hrDrm WestVillage',
#  'Renovated Big Private Room # 3',
#  'Brownstone - Garden level - 2 rooms',
#  'Fresh, Simple Sleep in Brooklyn!',
#  'Bedroom in Williamsburg Brooklyn',
#  'Unique 3BR Triplex in Brooklyn',
#  'Elegant SOHO One Bedroom',
#  'A Nest in Brooklyn',
#  '★HUGE beautiful E. Villager 2nd Av★',
#  "BROOKLYN'S FAVORITE BROWNSTONE in HIPSTER BED-STUY",
#  'GREAT 1BR apt 162st at Amsterdam av',
#  'Private Room in Brooklyn, NY',
#  'Central, Peaceful Semi-Private Room',
#  'Gorgeous sky-lit 2BR',
#  'Cozy & Private 1 Bedroom Garden Level Apartment',
#  'Saratoga Park Suite',
#  'sunny beautiful studio apartment',
#  'Zen Supersized Master Suite',
#  'Private Bedroom WITH a Living room!',
#  'JFK Jupiter Suites w/ Parking',
#  'Jupiter Suites- Rm #1 (JFK)',
#  'Bedford Stuyvesant Urban Hang Suite',
#  'VERY BIG, BEDROOM/ PRIVATE BATHROOM.',
#  'Cozy w/amazing city views by PS1',
#  'Jupiter Suites- Rm #2- (JFK)',
#  'Jupiter Suites, Rm #3- (JFK)',
#  'Master Bedroom in Modern Loft Apt.',
#  'West Village/SoHo Prvt Rm',
#  'small room in bedstuy P',
#  'Private, quiet Antique room on first floor duplex',
#  'Private room in 2 bedroom apartment',
#  'AMAZING, HUGE NEW YORK LOFT!',
#  'modern, convenient safe Midwood, Brooklyn',
#  'Boutique Williamsburg Duplex Apartment',
#  'Cozy',
#  'EV, Hippest East Village',
#  'nice room in bedstuy L',
#  'SPECIAL OFFER* 1BDR IN EAST VILLAGE',
#  'Private Bedroom in QUEENS',
#  'SALE- SUNNY MASTER BEDROOM NEAR MANHATTAN',
#  'Luxury Gramercy Lg 1Bd w Balcony',
#  'Designer Home in Village Center',
#  'SUNNY STUDIO MIDTOWN EAST W/DOORMAN',
#  'An artist place in Bedstuy',
#  '1 bedroom apartment in NYC',
#  'One bedroom apartment - UES',
#  'GRACIOUS HARLEM 1 BEDROOM',
#  'GREAT BRAND NEW 1 BED! TIMES SQ!!!!',
#  'COZY GARDEN APT IN BKLYN BROWNSTONE',
#  'Art House Suite',
#  'Private room in  MANHATTAN NYC',
#  'Beautiful Cozy Room Great Price!',
#  'One very large room two beds',
#  'SAFE BUDGET IN  Brooklyn  NYC',
#  'CHARM Rm HAMILTON HEIGHTS Harlem',
#  'BROOKLYN FAVORITE VACATION HOME 2',
#  'Nice and quiet',
#  'Gorgeous 1-2 bedroom(Prospect park)',
#  'Sunny 1BR + Outdoor space [L line]',
#  'Top floor 1 bedroom soho/nolita',
#  'BIG BROOKLYN HOUSE TO LOVE',
#  'Sunny, Large (Queen Bed) Private room in 2Bedroom',
#  'Williamsburg Brooklyn, Parkside Penthouse NYC View',
#  'Relaxing, serene room in NYC Apt',
#  'LARGE PRIVATE BED + BATH, LES',
#  '1 Bedroom in Greenwich Village',
#  'THE LINCOLN PARLOR',
#  'Museum Mile Central Pk- Madison Ave',
#  'Beautiful 1 bdrm in 2 bdrm apt',
#  'Harlem Oasis',
#  'Large, bright Williamsburg room',
#  'nice room in bedstuy B',
#  'Stunning  Limestone  1 Bdrm Flat',
#  'SUNNY,SUPER CLEAN WEST VILLAGE  APT',
#  'Queen size room in Brooklyn',
#  'Invitation to travelers',
#  'R & R In Harlem',
#  'Private Room',
#  'Urban Jungle in Bedford Stuyvesant',
#  'Large 2BR apartment East Village',
#  'LOCATION LOCATION LOCATION Abigail',
#  'Just like home & more in Rm #2',
#  'Cosy Brooklyn NYC One Bedroom in Garden Level',
#  'Beautiful warm duplex apartment',
#  'Private bedroom in awesome loft apt',
#  'Cozy apartment available!',
#  'Sunny & Budget Friendly',
#  'Private, Peaceful Times Square 1BR',
#  'Big, bright, Williamsburg bedroom',
#  'Apt near Museum Mile',
#  'Large Garden Apartment',
#  'Spring in Ditmas Park Brooklyn!!!',
#  'Zen & Cozy 2Bedroom in Williamsburg',
#  'PRIVATE ROOM #2 STARTING AT $67 PER NIGHT',
#  'One Bedroom in an apartment',
#  'Beautiful, large, charming spot',
#  'Futon 2.0',
#  'BEST PRICE - WILLIAMSBURG 1 ROOM',
#  'HEART OF NYC! AMAIZING LOCATION!, SUPER ROOM',
#  '3 Story Brooklyn House - Sleeps 10!',
#  'Awesome Harlem House 3 bdr 2 floors',
#  'Huge Garden Duplex, 20 min Manhattan!',
#  'Huge 2 Bedrooms NYC ',
#  'FIVE STAR LIGHT-FILLED DUPLEX - PRIVATE DECK',
#  'Private Backyard! Beautiful 1BR apartment.',
#  'BRIGHT AND SPACIOUS 3 BEDROOM WITH GARDEN',
#  'Bright & Budget Friendly',
#  'nice room in bedstuy A',
#  'Home Sweet Room-HOMEY-Queens NYC!!',
#  'Private Studio in Private Home',
#  'LOVELY 1 BEDROOM APT, BATH + KIT+ LIVING ROOM',
#  'Cozy Private room in Brooklyn',
#  '☆ DESIGN Spacious ☆ 1 BR Sleeps 4 Brooklyn Museum',
#  'Front Studio in Loft Apartment - Steiner Studios',
#  '1BR in HARLEM...SUNNY & SPACIOUS',
#  'Art Boutique 2BR Suite at JFK Airport',
#  'Room B',
#  'Boutique Hip Hotel Feel, WiFi, NetFlix, Private',
#  'Private room  D',
#  'Bushwick Calabrese Abode',
#  'Garden Oasis, Williamsburg!        ',
#  'Brooklyn garden 2 bedroom',
#  'Huge, gorgeous apt in Harlem, NYC',
#  'Live like a native',
#  'Hidden gem in Fort Greene',
#  'Nice bedroom',
#  'Stunning UWS studio private room;',
#  'SPACIOUS APT BK/QUEENS w/BACKYARD!',
#  'Entire 2 BED APARTMENT - WILLIAMSBURG- Best Price',
#  'Sunny Private room in Brooklyn',
#  'Beautiful Central Park Apartment',
#  'GREAT COZY APT',
#  'Private Bedroom in Sunnyside, NYC ',
#  'COZY ROOM WITH STUNNING VIEW IN AN AUTHENTIC FLAT',
#  'Private Bedroom in LIC/ Astoria',
#  'East Village Studio',
#  'BIG, BRIGHT, STYLISH + CONVENIENT',
#  'Herkimer House',
#  'BEDROOM WITH PRIVATE BATHROOM',
#  'Sunny Brooklyn Home',
#  'Large Wiliamsburg Private Bedroom',
#  'Elegant private studio in Manhattan 73 St. & 3 Ave',
#  '2 Bedroom Greenwich/Soho Apartment',
#  'Paddy Pad',
#  'Gorgeous 1 bdrm in Carroll Gardens',
#  'SUPER SUPER BOWL PAD',
#  'Midwood Aerie - Bright  & Private!',
#  'SPACIOUS BEDROOM AND PRIVATE BATH!!!',
#  'Peaceful Parlor Floor Apartment',
#  'La ponderosa',
#  'URBAN CHIC VIDEO/PHOTO SHOOTS ONLY',
#  'Chez Jazz BnB--Cozy BK/Queens room',
#  'Times Square Area Quiet + Private Guest Studio',
#  'New 1-Bdrm, 3-beds in Bensonhurst, Brooklyn, NY',
#  'SALE 2 BEDROOMS, LARGE MASTER & GUEST BEDROOM',
#  'A Simple, Calm Space',
#  'Williamsburg 1 bedroom appartement',
#  'Private Room Brooklyn NY',
#  'Quiet & private room in luxury doorman bldg',
#  'Beautiful Central Park Apartment!',
#  'Overlooking Harlem',
#  'Royal Harlem TRIPLEX Home 5 Beds',
#  'Ingefära Hus! One bedroom Williamsburg, Brooklyn',
#  'HUGE LUXURY 2BD/2B, 7mn TO TIME SQR',
#  '3 BEDS IN LOVELY 2BEDROOM/2BATH MIDTOWN RENTAL',
#  'Close to Maimonides Center. Room D',
#  'Apartment 6',
#  'Williamsburg Bedroom & Study',
#  'Charming Modern Studio w/Large Garden',
#  'Large Private Room',
#  'Budge private room F',
#  'Beautiful Prime Williamsburg Apt',
#  'Carroll Gardens entire apartment',
#  'Quiet Queens Apt in middle of NYC',
#  'GORGEOUS LUXURY APARTMENT AND VIEW!',
#  'Fort Greene 2 bedroom Apartment',
#  'Huge Modern Waterfront Home',
#  'Comfortable bedroom for one person',
#  'Large Two Bedroom Brooklyn Loft',
#  'GREAT FOR FAMILIES AND GROUPS!!!',
#  'Modern Sunny 2-Bedroom in Bushwick',
#  'Union Square spacious studio',
#  'Bayview room',
#  'East Village Manhattan NYC Bedroom!',
#  'Brooklyn Studio',
#  'Experience ELEGANT LIFESTYLE',
#  '1 Bedroom East Village, NYC',
#  'cozy room /female guests',
#  'Beautiful Studio Suite! Upper East',
#  'nice room in bedstuy D',
#  'Entire Private Modern Studio UPW Manhattan',
#  'Cozy private room in beautiful apt',
#  'Pvt Bedroom in Williamsburg Central',
#  'Urban Holiday...',
#  'Quiet & Central West Village Artist’s 2 Bedroom',
#  ' garden view  / female guest ',
#  '2 BR Sun Filled Feng Shui W Village',
#  'Boerum Hill 2BR Garden Apartment',
#  'Large 1 bdrm, River views!',
#  '3 Bedroom @ JFK CASINO BEACH LOCALE',
#  'Location  Queen Elena',
#  'Film Location',
#  'Large 2 Floor Apt 2 Bdrm Sleeps 8 ',
#  'A beautiful modern 3 bedroom apt',
#  'Sunny Manhattan Studio',
#  'Private cozy room',
#  'Bright Brooklyn garden apartment!',
#  'Old World Garden Apartment',
#  'Big Private room in Brooklyn Brownstone',
#  'Dani private room in Manhattan',
#  '2 Queen beds Studio Loft in Brooklyn',
#  'Quiet bedroom in East Village NY.',
#  '1 bedroom  in  Nolita/Soho',
#  'Times Square Unique Studio',
#  'Amazing Private Room in Brooklyn - Fort Greene',
#  'Quite 2 bedroom apt. in Brooklyn',
#  'Gramercy Luxurious 2 BD condominium',
#  'PRIME WILLIAMSBURG FAMILY ART LOFT',
#  'Cozy Studio Close to Central Park',
#  'Large  Sunny Open Brooklyn Apartment',
#  '2 Bedroom Garden Apt. Park Slope',
#  'Orchard St',
#  'Private 3 Floor Whole Hse/Garden',
#  'Brooklyn Cozy Garden Apt',
#  'West Village designer studio',
#  'Quiet 1BR in Chelsea',
#  'Close to JFK & LGA Feels like home',
#  'Brooklyn Garden Level  2bdrm Home',
#  'Super cute private room +amminities',
#  'Great Apt,  Great Area',
#  'Cozy quiet East Village room/en suite bathroom',
#  'Beautiful Clean & Quiet Room! Rm#1',
#  'Cozy bedroom in Brooklyn!',
#  'Garden apt 15 mins from Manhattan',
#  'LEGAL studio in Queens',
#  'Central Park West. Queen Size Room',
#  'west village 1BR!best value!',
#  'Park Slope Haven',
#  'Good Living in Brooklyn! Double Bed',
#  'Spacious and unique 1 bdrm / 2 bath',
#  'Williamsburg Garden Apartment',
#  'Your NYC haven at Upper Manhattan!',
#  'Suite Lounge',
#  'COOL, ARTSY & CENTRAL APARTMENT',
#  'Sweet 2 bed in Elevator Building',
#  ' 3 bedroom loft in Williamsburg',
#  'Luxe Tuscan Suite Private Room',
#  'Modern & Cozy 1BD Garden Apt',
#  '☆ PERFECT MANHATTAN LOCATION NEAR SUBWAY & CAFES!☆',
#  '5-Star Park Slope Suite w/King Bed',
#  'Red Hook Prime 1 BR Priv. Garden 3 blks NYC Ferry',
#  'Location little Elio',
#  'Lovely room in doorman building',
#  'AMAZING ROOM ARTSY BKLYN BROWNSTONE',
#  'Gallery Suite',
#  'Charming Brooklyn Room',
#  'Cozy/Hip LES 2 bedroom, sleeps 2-4',
#  'Zen Loft: Huge Brooklyn Loft for Shoots & Events',
#  'Serene, minimalist studio W Village',
#  'Entire Room Brooklyn NYC!!!',
#  'Williamsville Sleep & Stay',
#  'Huge modern Private room available',
#  "Brooklyn's Finest",
#  'Cozy room in NYC',
#  '7even Days Sleep Near Prospect Park',
#  'Serengeti Comfy APT',
#  "PRIVATE BEDROOM YOU'LL LOVE",
#  'Comfy, convenient bedroom in Bklyn!',
#  'Private bedroom apartment 4B',
#  'Private bedroom apartment 4B/2',
#  'Beautiful Apt x Rent in Astoria, NY',
#  'Beautiful Clean & Quiet Room! Rm#2',
#  '3 Bedroom Duplex',
#  'Luxurious Brooklyn 2BD w/ Parking',
#  'Sunny/Cozy 1BD',
#  'Cozy Vintage Artist Flat(Williamsburg/Bushwick)',
#  'Beautiful Large Sunny Bedroom',
#  'Per/night Room Brklyn New York',
#  '(Hidden by Airbnb) ! BrooklynCleanRoom!!',
#  'West Village Loft, 2nd floor',
#  'THE BEST HOUSE IN BROOKLYN !',
#  'Reno 2BR~prime union squar~',
#  'Quiet spot in NYC',
#  'GREAT ONE BED! ELEVATOR/LAUNDRY ',
#  'Perfect mid summer apart available',
#  'Bright, cozy den in 4 bedrm duplex.',
#  'Studio apartment',
#  'cute convenient village suite',
#  'Luxury Studio on (Email hidden by Airbnb)',
#  'Metro-luxe Tuscan Suite Private Room',
#  'west village 1BR!best value!',
#  'private bedroom in NYC apartment',
#  'Beautiful West Village 1 BR Apt--Best Location!',
#  'Cozy Private Bedroom',
#  'Master Bedrm, Steam Shr/Jacuzzi, FH',
#  '5107-Studio Doorman GYM LuX',
#  'Colorful 2 Bedroom in Brooklyn',
#  'Brooklyn 2 bedroom Apartment',
#  'Home, Sweet Home!',
#  'Beautiful Terrace Room',
#  '1 Bedroom w/ huge Deck in West Village/SOHO',
#  'L',
#  '5146-Doorman Pool!1 bedroom View',
#  'private Greenpoint apt',
#  'Beautiful -  Upper West Side ',
#  '5136-Doorman 2 bedroom 3 beds!',
#  '5132- Huge Studio! SWIMMING POOL',
#  'Clean/nice Suite 5m T LIRR,B,Q65,13',
#  'Private room',
#  'Fort Greene Gem',
#  'Upper West Side Museum/Central Park',
#  'XL Fort Greene Garden Apt',
#  'JFK/LGA Queens Modern Apt.',
#  'ENTIRE FURNISHED 1BD APT.',
#  'Large 3 bedroom on Upper West Side',
#  'Bedford Avenue',
#  'LL2',
#  'SUNNY HUDSON RIVER VIEW   2BATHRM APT NEAR SUBWAY',
#  'Entire apartment 1st Floor',
#  'Beautiful 1 bedroom in NYC',
#  'ECO-CHIC PALLET DESIGN APARTMENT',
#  'Brooklyn Garden Apartment ',
#  'SPACIOUS STUDIO-HIGH END FINISHES',
#  'Clean Bedroom in Greenwich Village',
#  'Brooklyn 1 BR Near Subway',
#  'Private Room A',
#  'Stuvesant East',
#  '"DECO CASA"  2 Bedroom Greenpoint Brooklyn',
#  'Quiet Haven in Park Slope Huge 2BR',
#  'Brooklyn modern 2 BR Garden Floor',
#  '1 BDR APARTMENT  7 MINS FROM JFK 5 STAR RATED',
#  'Stunning Parlor Garden Apartment',
#  'DO DROP IN, LLC',
#  'Forest Hills Villa 皇后区“曼哈顿”-森林小丘别墅!',
#  'Soho 1 Bedroom',
#  'THE THOMPSON SUITE',
#  'Bklyn, private Three Bedroom.',
#  'Private Single Room',
#  'Art deco apartment in Brooklyn',
#  'Master Bedroom 别墅二楼主卧房',
#  'Quiet Two Bedroom Apartment ',
#  'Cute 1 bedroom apt in East Village',
#  'Beautiful SUNLIGHT in quiet apt!',
#  'LUXURY entire apt, steps to Central Park',
#  'Basement 别墅的地下室',
#  '1 Bedroom & Semi- Private Living Area',
#  'Happy cozy Manchi GUEST ROOM',
#  'MODERN AND COZY FLAT w/ BACKYARD',
#  'Quiet bedroom in a waste free household',
#  'WilliamsburgBrooklynPrivateBedroom',
#  'Urban Jungle Garden Duplex',
#  'Brooklyn - Boerum Hill Beauty',
#  'Cozy Bedroom',
#  'Cozy Home w/Private Garden&Hot Tub!',
#  'Big 2BR, just minutes to Manhattan!',
#  'Small Private Studio!',
#  'Williamsburg Beauty',
#  'BEST LOCATION in MANHATTAN!',
#  'Appartement en duplex de 3 chambres',
#  'Charming, private 1BR garden apt',
#  "Private bedroom in Hell's Kitchen",
#  'Wyndham 45 Midtown NYC',
#  'Garden Oasis Apartment - 2 bedroom',
#  '1 Bedroom in Greenwich Village!',
#  'NICE SPACE IN NYC ',
#  'Awesome Chelsea 1 bedroom',
#  '10 Minutes to Manhattan',
#  'Cute ethnic cosy private studio!',
#  'Wonderful Willi!',
#  'Upper East Side 1-Bedroom',
#  'Central Harlem large beautiful studio',
#  'Cozy 1 bdrm Park Slope, Brooklyn,',
#  'Room #1 Private Room',
#  "Livin' La Vida Brooklyn!!!",
#  'Beautiful Beach  & Great Space',
#  'Double-deck bed room 别墅二楼卧房',
#  'GORGEOUS 2 Bedroom in Queens NYC',
#  'Retreat Room',
#  'Convenient  Harlem studio',
#  'Sunny 2BR, 2BA duplex',
#  'Sunlit 1 bedroom in NoLita',
#  'East Village Bedroom',
#  ' 2-3 bedroom UWS garden triplex ',
#  'Beautiful Upper West Side',
#  'Superhost 3 bedroom DISCOUNT',
#  'cozy queen for 2 in el barrio',
#  'Twin  room',
#  'Flatbush Gardens',
#  'Beautiful Chelsea 2 Bedroom apt',
#  'Dorm Sz Room. Near 2 & 5 train 180 st Bronx zoo',
#  "B's Suite",
#  "B's Elegant Parlor Suite",
#  'Upper West Side Studio doorman bld',
#  'Large Sunny 2 Bedroom + den - UWS',
#  'Large, Luxury Bedroom nr JMZ subway',
#  'Zen Oasis in Bushwick, near JMZ Subways',
#  'Landmark 1 Bedroom has 2 beds, Free WiFi',
#  'SPACIOUS,  2 bedrooms, sleeps 4, private bath',
#  'Your Brooklyn Nook',
#  '$99 Manhattan/Time Sq.',
#  'MIDTOWN APARTMENT WITH SPECTACULAR VIEW',
#  'Zen Den & Modern Outdoor Space',
#  'Vintage Room  in  Brooklyn',
#  "1 Bedroom Apt in Hell's Kitchen !",
#  'BRIGHT MODERN BEDROOM',
#  'LOVELY  LARGE SUNNY ROOM    Sunset Park',
#  'Big Kitchen, Beautiful Bathroom',
#  'Brooklyn - Funky 1 Bedroom',
#  'Super Quiet, Private Patio',
#  'Beautiful Astoria apt next to Mtan',
#  'Room in queens covenient safe locat',
#  'Upper East Side',
#  'Manhattan! Bunk beds for 10+',
#  'SUNNY GUEST BDRM in Fort Greene!',
#  'Unique 2 Bed/2 Bath Duplex Apt',
#  'Best value double room in New York B4',
#  '1 Bdrm in Greenwich Village',
#  'Master Bedroom by Yankee Stadium',
#  'West Village upscale apartment',
#  'Adelphi Garden Apartment',
#  'Cozy Garden Apartment in Bushwick!!',
#  'PEACEFUL NYC 2-Bedroom FLAT',
#  'Master Bedroom in E.Village Triplex',
#  'Skyline View Piano Room',
#  'Harlem Renaissance',
#  'VIEWS VIEWS VIEWS from Designer Apt',
#  'Cozy Harlem Escape 20 mins to Times Square',
#  'My home in West Village--Huge, Modern',
#  'West Village / Bleecker & Cornelia',
#  'Heaven On Riverside',
#  'Nirvana On Riverside',
#  'Roomy/sunny/quiet/fun/great locale',
#  'Large queen size bedroom in huge loft apt',
#  'Queen size bedroom. 15 min to NYC',
#  'Five star large one bedroom!',
#  'Sunny Bedroom in BK',
#  'SOHO GALLERY',
#  'Private 1st level studio near NYC',
#  'HOUSE SUITE',
#  "Quiet, value & convenience in NYC's best hood!",
#  'Cozy 1-bedroom apt ',
#  'Beautiful, sunny, large 1BD!',
#  'Sugarhill  Studio',
#  'Cozy, CLEAN & SAFE room',
#  'Times Square Cozy Studio ',
#  'Quiet retreat, peaceful stay',
#  'Amazing 2BR (5) UES, (MIN 30 DAYS)',
#  'Modern Living',
#  'Private bedroom',
#  'Basement apartment in bedstuy',
#  'Clinton Hill Guest Room',
#  'STUNNING 1BD BRIGHT UNIT, RENOVATED',
#  'Happy Brooklyn! Happy Konakolo!',
#  'Gorgeous quiet & central NYC apt!',
#  'LARGE COZY STUDIO BEST LOCATION - PARADISIAC OASIS',
#  'VICTORIAN SUNFILLED APT DREAM VIEW',
#  'Boutique Retreat',
#  '*DYLAN* Exquisite 1 BR & Terrace - Contemporary',
#  'Beautiful sunny apt near prospect park!',
#  'Central Park Suite',
#  '*OASIS* 2 BEDROOM, 2 BATH & Garden! Great UWS Area',
#  'Big & bright 2 bedroom apartment! Lower East Side!',
#  'HUGE 1 BED@TIMES SQUARE@BRAND NEW!!',
#  'Amazing Central Park view',
#  'Beautiful Central Park View',
#  'cozy room 5 minutes to manhattan',
#  '汤母小屋',
#  'Upper East Side Gem!',
#  'PRIME LOCATION - Beautiful 3BR Artist Oasis w/Deck',
#  'Simple, sweet in NOLITA-NYC',
#  'Restored 1910 Brooklyn Loft Suite',
#  'Large Room in Greenwich Village',
#  'Private Bedroom in Upper Manhattan',
#  'near Columbia Hospital',
#  'Master bedroom in Williamsburg',
#  'BEAUTIFUL 2 BED/ BRICK WALLS/ 52ST',
#  'Cozy one-bedroom in E Village',
#  '*Designer West Village Dream Home*',
#  'Convenience & Chill',
#  'Perfect One Bedroom in Greenpoint',
#  'Huge 1 Bedroom in East Harlem',
#  'Amazing BR in Doorman Building!',
#  'FANTASTIC MANHATTAN LIVING 5 day Minimum',
#  'Metro Retreat  - - Harlem',
#  'Cozy, Convenient, Clean & Colorful!',
#  'Upper West Nest',
#  'Chez Louise sunny BK garden apt.',
#  'Feel at home',
#  'UES LRG 1BR SLEEPS 4~61ST~Gr8 value',
#  '2 BEDROOM IN MIDTOWN EAST',
#  "Gem-like UES writer's studio",
#  'Cozy Garden Flat.',
#  'Remsen Village Rental',
#  'NEW YORK CITY!!! LOCATION LOCATION!',
#  'SUN FILLED 1BR in ARTSY FORT GREENE',
#  'Apt available - Best NYC Location',
#  'Cozy Room',
#  'Unique NYC Loft - Guest Room',
#  'Beautiful 1BD/ NEW RENOVATIONS/ELEV',
#  '纽约之家(Sunnyhome7)',
#  'Fabulous studio UES 30 days min',
#  'Beautiful private suite-like 2FL apt. West Village',
#  'Sunny Park Slope Bedroom',
#  'Private room in 2/bed doorman condo',
#  'Union square~reno Studio~Terrace',
#  'clean, quiet, 1 bdrm, great locale',
#  '4 Bedroom Apt On Kissena Park in NYC',
#  'nice room in bedstuy F',
#  'Beautiful Artist loft',
#  'Amazing HK one bedroom apartment',
#  'Sunny spacious private unit close CENTRAL PARK!',
#  'Bushwick Artist Loft',
#  'Modern, renovated garden apartment',
#  'Chez Jesse Vacation Spot - Garden',
#  'Oasis in Kensington',
#  'Modern 1 Br Apartment',
#  'CLEAN & COZY EAST VILLAGE PAD',
#  'Beautiful MASTER BEDROOM East side C7',
#  'Cozy bedroom in Brooklyn Sunsetpark',
#  'Village One Bedroom',
#  'Gorgeous Studio in Greenwich Village',
#  '2 bedroom home in Brooklyn',
#  'Park Block Studio',
#  'Your Brooklyn Nest',
#  'Beautiful Room Near S. St. Seaport',
#  'REAL LUXURY my SUNNY alcove studio',
#  'Large, sunny, private studio Apt 2R',
#  'Park Slope center Garden Studio  ',
#  'Sleeping in NYC, like home.',
#  'BEAUTIFUL APT UPPER WEST SIDE, 68St ONLY GIRLS',
#  "Cozy Quiet 1 BR Apt Hell's Kitchen",
#  '2 Bedroom, Doorman. Roof deck. Skyview!',
#  'Lower East Side Minimalist Studio',
#  'Brooklyn Soul',
#  'Sleeping in NYC, like home (1).',
#  'Cozy Harlem Stay',
#  'Large private room on quiet street',
#  '3 bedroom Apt at $249 per Night.',
#  'Long term sublet Brooklyn',
#  'East Village -  Beautiful 1 Bedroom',
#  'one large private bedroom/ two bedroom apartment',
#  'SUNNY ROOM A IN CHARMING AREA :)',
#  'CHARMING ROOM W/ ROOF DECK ACCESS 1 :)',
#  'Large, sunny, private studio Apt 2F',
#  'Room in 3 bedroom apt.',
#  'Hotel Gabrielle',
#  '2 Flushing Sunny Garden View 舒适阳光房',
#  '1-BdRm Entire Apartment St. George',
#  'Large BED in Amazing LIVING SPACE',
#  'views to die for apartment on water',
#  '1bd garden apartment in Fort Greene',
#  '`AMAZING BROOKLYN HOME',
#  'Park Slope, Sunny, Private, Quiet, 2 Bedroom',
#  'BRAND NEW HUGE 1 BED@TIMES SQ!!!!!!',
#  'As seen on Netflix! Bright, 3-bedroom in Red Hook',
#  'BEST LOCATION 12ST BY UNION SQUARE',
#  'FABULOUS SUNNY BEDROOM IN HARLEM',
#  'Beautiful 1BR in West Harlem!',
#  'Delightful Brooklyn digs!',
#  'Big Manhattan Apartment 3 bedrooms big Living Room',
#  'Home On Kissena Park in Flushing NYC',
#  'A Modern 1 bedroom Apartment in Brooklyn',
#  '4 bedrooms private house',
#  '1 BR UPPER EAST SIDE',
#  'Nice cozy studio apt close to all',
#  "Hell's Kitchen 1 Bedroom",
#  'Beautiful HUGE Studio.. 52ST 3AVE.',
#  'Amazing 2 Bedroom Chelsea',
#  'Large Alcove Studio',
#  'SPACE IN APT IN PERFECT LOCATION',
#  'A Gem in Fort Greene Brooklyn',
#  'Solo traveler oasis',
#  'Relaxing Brooklyn Getaway',
#  'Wonderful Large 1 bedroom',
#  'Modern Vibrant Large Cozy Bedroom* 正面能量',
#  'Zen urban sanctuary.',
#  'Beautiful Room near L train',
#  '1 bedroom in a 2 bedroom apartment',
#  'Brooklyn Zen Gem Serenity Bedroom',
#  'NEW YORK CITY WITH AN OCEAN BREEZE',
#  'Ensuite Redroom',
#  'Orange Room',
#  'NYC space',
#  'Park Slope Garden Level Studio',
#  'Strawberry Fields',
#  '近地铁及市中心,干净 NYC 30 min to Manhattan',
#  'Brooklyn Zen Gem Restful Retreat',
#  'Modern Quiet Gem Near All',
#  'Beautiful Boerum Hill 2 Bedroom',
#  'GORGEOUS BEDROOM IN VICTORIAN HOME W/PRIVATE BATH',
#  'Cozy, quiet and comfortable 1BR',
#  'Ensuite Turquoise Room',
#  '2-Bdrm Entire Apartment St. George',
#  'Nice Cozy Space',
#  'SPACIOUS WILLIAMSBURG DESTINATION',
#  'Brooklyn private room',
#  'Modern& Pretty Bedroom UpperBest!!!!',
#  'Entire Prime Upper West Side Large Studio',
#  'Gowanus Brooklyn Bed',
#  'Huge private bedroom for quiet sleep in Manhattan!',
#  'GARDEN OASIS CLINTON HILL BROWNSTON',
#  'Room in Condo',
#  'Beautiful 2bdroom apartmnt',
#  "Dominique's LowerLevel 1 bdrm pad*video projects",
#  'My Little Guest Apartment',
#  'LUXURY DOORMAN HIGH RISE One Bedroom',
#  'COBBLE HILL BROWNSTONE',
#  'A True Gem.',
#  'Cozy private room in Brooklyn, NYC.',
#  'Private room',
#  '2 Bdrm apt Near Empire State Building',
#  'BROWNSTONE BUILDING IN CLINTON HILLS',
#  'NICEQUIET10 MINUTES TO TIME SQUARE.',
#  'Gem of Bushwick',
#  'Casa de la Luna -Bedford Stuyvesant',
#  'Home Sweet Home :)',
#  'Room for rent in corona queens',
#  'NYC ROOM GORGEOUS LIGHT! RIVER VIEW',
#  'Spend Summer in Park Slope',
#  'Brooklyn Zen Gem Spacious Bedroom',
#  'WoodyAllen FilmSet-Like Digs (Apt)',
#  '1 bedroom-Manhattans East Village',
#  'WoodyAllen FilmSet-Like Digs (Room)',
#  'Entire 1 Bedroom Apt',
#  'Bedroom in FABULOUS W. Village Apt!',
#  'Gorgeous Garden Apartment in Park Slope',
#  'Amazing Bright bedroom in Harlem',
#  'Duplex Suite Sleeps 8',
#  'GC Bushwick First Floor 4 Bedroom',
#  '1 Bedroom in Williamsburg!',
#  'Large Williamsburg (Brooklyn) Room',
#  'COZY CORNER GREENWICH VILLAGE',
#  'Modern Room in Huge Apartament in Manhattan',
#  'Beautiful and sunny',
#  'Size, Splendor & High Ceilings',
#  'PRETTY CLINTON HILL BROWNSTONE!',
#  ...]

# %% [markdown]
# A method around this is to limit the # of possible languages (using langid) and for entries that are not in english, we can remove those titles and give a sentiment score equivalent to the average of the respective neighborhood. From the world_atlas, the most common languages spoken in NYC are: English, Spanish/Spanish Creole and Chinese [2]. To get more accurate results, we should remove any characters that are not used in proper english (i.e. hypens, slashes, asterisks etc.)
#
# [2] https://www.worldatlas.com/articles/how-many-languages-are-spoken-in-nyc.html

# %%
def grammar(string):
    # add whatever else you think you might have to account for
    result = str(string)
    result = result.replace('/', ' ')
    result = result.replace('*', ' ')
    result = result.replace('&', ' ')
    result = result.replace('>', ' ')
    result = result.replace('<', ' ')
    result = result.replace('-', ' ')
    result = result.replace('...', ' ')
    result = result.replace('@', ' ')
    result = result.replace('#', ' ')
    result = result.replace('-', ' ')
    result = result.replace('$', ' ')
    result = result.replace('%', ' ')
    result = result.replace('+', ' ')
    result = result.replace('=', ' ')
    
    return result

# %%
import langid
desc = description.apply(grammar)
langid.set_languages(['en', 'es', 'zh'])
not_en = []
not_en_index = []
i = 0
for title in desc:
    if langid.classify(title)[0] != 'en':
        not_en += [title]
        not_en_index += [desc.index[i]]
    i += 1
    
len(not_en)
# Out:
# 1745

# %% [markdown]
# While a couple of the names that were categorized as not english are still in english, we were still able to obtain a greater # of accurate samples.

# %%
not_en
# Out:
# ['Spacious 1 bedroom in luxe building',
#  'West Side Retreat',
#  'Sunny   Spacious Chelsea Apartment',
#  'Spacious luminous apt Upper West NYC',
#  'Spacious Prospect Heights Apartment',
#  'Sun drenched, artsy modernist 1 BDRM duplex',
#  'Bright Spacious Luxury Condo',
#  'Designer 1 BR Duplex w  Terrace  Spectacular Views',
#  'Spacious Williamsburg Share w  LOFT BED',
#  'Spacious 1BR, Adorable Clean Quiet',
#  "DOMINIQUE'S NY mini efficiency  wifi metro quiet",
#  'Bright Spacious Williamsburg Abode!',
#  'Lovely, Modern, Garden Apartment',
#  'Spacious Loft in Clinton Hill',
#  'UES Quiet   Spacious 1 bdrm for 4',
#  'Spacious Brooklyn Loft   2 Bedroom',
#  'Park Slope Apt:, Spacious 2 bedroom',
#  '☆Massive DUPLEX☆ 2BR   2BTH East Village 9  Guests',
#  'Luxe, Spacious 2BR 2BA Nr Trains',
#  'Private, spacious room in Brooklyn',
#  'Greenpoint Spacious Loft',
#  'Large  Loft Style  Studio  Space',
#  'Cool   Spacious Harlem Artist Flat',
#  '☆ STUDIO East Village ☆ Own bath! ☆ Sleeps 4 ☆',
#  'Sunny, quiet, legal homelike suite Pk Slope South',
#  'spacious studio',
#  'Ultra Modern NYC Garden Apartment',
#  'Spacious   Comfy BK Brownstone',
#  'Large room in elevator drman bldg',
#  'Serene Park Slope Garden Apartment',
#  'Comfortable. Spacious. Private Room.',
#  'New Clean Spacious Bed   Breakfast',
#  'Wonderful Studio In Brooklyn, NY!!!',
#  '✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿',
#  '✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿',
#  'Spacious   Stylish Chelsea One Bedroom Apartment',
#  'Spacious Townhome Apt in Brooklyn',
#  'Bright unique designer loft in Soho',
#  'Spacious  2 bed Loft apartment Bedford L',
#  '2 Bedroom Gem   Prime LES Location',
#  'Charming furnished Studio Loft',
#  'Spacious East Village Apartment',
#  'Spacious 2BR near Botanic Garden',
#  'LUXE Privé L.I.C. Apt   Garden',
#  'Chic, Spacious Loft   Backyard',
#  'Serene Room ',
#  'UNION SQUARE❤️PENTHOUSE 2FL TERRACE❤️EAST VIllAGE',
#  'Bright Spacious 2 Bedroom 5 Room   wRoof Deck',
#  'PRIVATE Room in Spacious, Quiet Apt',
#  'Beautiful, Spacious 4 BR Brooklyn Brownstone',
#  'Spacious Apartment w extra room',
#  'Spacious Upper West Side 1 Bedroom',
#  'Gorgeous Unique Garden Terrace Apt.',
#  '☆ 2BR East Village ☆ Sleeps 5 | BEST LOCATION ☆',
#  'large spacious room',
#  'Spacious Stylish  2 Bedroom Suite',
#  "Sweet n' Spectacular PARK SLOPE!",
#  'NYC Chelsea very spacious 1 bedroom apartment',
#  '1 BDRM, Good Light, Fire Escape, AC',
#  'Spacious Brooklyn Loft w  River View',
#  'Charming 2 Bdrm UWS w  private deck',
#  'Prime location near Central Park !!',
#  'Comfy apartment, adorable cat!',
#  'QUIET spacious 1BR, great location!',
#  'Your OWN Private Garden Apartment',
#  'Private Oasis, en suite bathroom',
#  '1 Bedroom Apartment in quiet area.',
#  'Spacious 1 Bedroom Apt, Prospect Hts Park Slope',
#  'Spacious Lower East Side Studio',
#  'Spacious 1 Bdrm in BEST location!!',
#  'Spacious Private Bedroom Brooklyn   Williamsburg',
#  'Spacious Sunny Union Sq Room',
#  '❤️Feel HOME Brooklyn Clinton Hill ❤️',
#  'Modern condo close to Prospect park',
#  'Spacious 3 Bedroom Prospect Brooklyn near subway',
#  'Clean,spacious,comfy Brooklyn room',
#  'Very Large Private Room on quiet st',
#  'Nice quiet room on a backyard',
#  'Spacious Bushwick Duplex Apartment',
#  'Spacious Comfy Bedroom in Bed Stuy',
#  'Gorgeous PermaGO HOMES™   FiDi   Room 2 2',
#  'Union Sq European Serene apt',
#  'Private Studio Near JFK, LGA   Subway  Not A Bsmnt',
#  'Fort Greene Jewel',
#  'Spacious 3br Apartment in Brooklyn',
#  'Comfortable Apt near Bloomingdales',
#  'BK   Spacious   Sunny 4 bedroom apartment',
#  'Spacious Room Great Location',
#  'Great Bushwick Studio Apartment',
#  '2BR spacious luminous brownstone',
#  'spacious PARK SLOPE room available ',
#  'Spacious Private Room  East Village',
#  'private spacious sunny bedroom',
#  'Spacious 2 bedroom near Times Sq',
#  'LARGE light filled loft apt! PRIME Williamsburg.✨',
#  'beautiful spacious room',
#  'East Village Bright   Spacious Artist Loft',
#  'Spacious Harlem Condo',
#  'Spacious   Stylish 2br Prime Williamsburg Hot Spot',
#  'Private spacious studio',
#  'Large, Quiet, Sunny 1 Bedroom Condo Williamsburg',
#  'Charming, Quiet,   Clean 1BR APT',
#  'English Basement Studio Apartment   private entry',
#  'Gorgeous spacious. 2 subways close',
#  'Sunny 1 Bdrm ❤️ Private Bath ❤️ No Cleaning Fee',
#  'Brownstone   Garden level   2 rooms',
#  'Spacious Factory Converted Loft',
#  'Modern, Art Deco Chelsea Studio',
#  'Saratoga Park Suite',
#  'Private, quiet Antique room on first floor duplex',
#  'Rare large modern garden studio, comfy; location!',
#  'Sunny Spacious Dwelling',
#  'Cute, quirky Park Slope Jr 1 bdroom',
#  'Bushwick Biodome Loft, Fun   Unique, Great View!',
#  'Large Spacious Apt For Sublet',
#  'Amazing Spacious Room',
#  '2000 SQ FT Spacious Artist Loft in SOHO',
#  'Large Studio w  Entertainment Room!',
#  'Sunny Spacious Retro 1 Bedroom',
#  'Spacious Room, Central Location, Historic block.',
#  'Beautiful Spacious 1 Bedroom in LES',
#  'Charming Spacious 1 Bdrm Apt',
#  'Prime East Village Spacious 1 BED',
#  'Private, Spacious Garden Apartment',
#  'Modern, spacious 2 BR, 2 Bath   BK',
#  'Large Garden Apartment',
#  '2Br East Village VERY Spacious Apt.',
#  'Spacious 1 bed near train!',
#  '☆ DESIGN Spacious ☆ 1 BR Sleeps 4 Brooklyn Museum',
#  'Boutique Hip Hotel Feel, WiFi, NetFlix, Private',
#  'Bushwick Calabrese Abode',
#  'Clean, spacious entire 1br in NYC!',
#  'Spacious Upper West side 2 bedroom apartment',
#  '❤️ 2 Beds Option   Private Bath, Sunshine Bushwick',
#  'Inspiring spacious loft space',
#  'Spacious 3BD 2BA   Parking Included',
#  'West Village Wonder  spacious 1 bed',
#  'Private Furnished Studio Apartment',
#  'Central Park West Studio Value',
#  'Brooklyn NY, Comfy,Spacious Repose!',
#  'Modern Large Studio, Great Location',
#  'Sun bathed spacious Luxury 2 BR near CENTRALPARK!',
#  'Modern Style private room in queens',
#  'SOHO   Large Studio Apt',
#  'Spacious Studio on West 72nd',
#  'La ponderosa',
#  'Charming Spacious Master Bedroom',
#  "Quintessential W'burg Apartment",
#  "Quintessential W'burg Private Room",
#  'Comfortable, spacious “ 1 bedroom “ apartment',
#  'Unique loft in Bushwick   Offices, yoga   roof!',
#  'Charming Modern Studio w Large Garden',
#  'GREAT 2bed 2bath patio, FORT GREENE',
#  'Spacious Studio Suite w Adjoining Sunroom',
#  'Quaint Room ',
#  'Fort Greene 2 bedroom Apartment',
#  'Charming Entire ❤️ apartment',
#  'Spacious 1 bedroom, prime location.',
#  'Union Square spacious studio',
#  'Spacious Studio Loft in Brooklyn',
#  '☀️Sunny Central Park North☀️',
#  'Cozy, Clean, Spacious Apartment!',
#  '2B   Private Garden A Williamsburg Spacious Escape',
#  'Spacious Junior 1BR Apt in USQ Flatiron',
#  '☆ Central Park   Home Away From Home',
#  'Lovely, Huge, Open, Quiet, Spacious, Sunny, A C',
#  'Spacious room in artist Loft',
#  'Cute UWS Studio Near Central Park Clean   Quiet',
#  'SOHO Studio Best Location',
#  '2 Bedroom Garden Apt. Park Slope',
#  'Private oasis charming gingerbread home!❤️❤️❤️❤️❤️',
#  'Cozy quiet East Village room en suite bathroom',
#  'Charming Quiet Apartment in NYC (安靜公寓)',
#  'Private Charming Spacious Bedroom',
#  'Spacious, Sunny 1 Bedroom Apartment',
#  '☆ PERFECT MANHATTAN LOCATION NEAR SUBWAY   CAFES!☆',
#  '5 Star Park Slope Suite w King Bed',
#  'Private Room In Clean Spacious Apt',
#  'Large   Spacious   Prime Location ',
#  'Discount! Central Clean   Quiet',
#  'Gramercy~Reno New 1BR Sleeps 4~',
#  '5144 Prime Doorman!78ST   Madison ',
#  'Bright   New Reno, Quiet Block',
#  'Reno 2BR~prime union squar~',
#  'Sunny Bedroom in El Barrio',
#  '★ Convenience   Comfort Awaits!  ♥️ Your Stay! ★',
#  'Spacious Studio in West Village!',
#  'Great Sunny Spacious Room',
#  'Studio apartment',
#  'Metro luxe Tuscan Suite Private Room',
#  'Private Studio Near Union Square',
#  '5107 Studio Doorman GYM LuX',
#  'Beautiful 1b Bloomingdales location',
#  'Spacious Studio in Time Square',
#  'Fort Greene Gem',
#  'XL Fort Greene Garden Apt',
#  'Spacious 1 Bedroom Apt in Brooklyn',
#  'Prime SoHo! shops, food, fun',
#  'Union Square~Reno 2BR~Great Value',
#  'Spacious Park Slope brownstone',
#  'Spacious Sunny 2BR Prime Greenpoint',
#  'Comfortable   Spacious Home in NYC',
#  'Large, Bright, Studio Style Bedroom',
#  'Unique room w 2 Twin beds..wifi metro  quiet safe',
#  'Forest Hills Villa 皇后区“曼哈顿” 森林小丘别墅!',
#  "DOMINIQUE'S NY chic   quiet room wifi metro",
#  'Spacious Bedroom, L.E.S.',
#  'Master Bedroom 别墅二楼主卧房',
#  'Beautiful SUNLIGHT in quiet apt!',
#  'Spacious Sunny Room',
#  'Basement 别墅的地下室',
#  'Studio Apt',
#  'Stylish 1 BedRoom very quiet Upper East Side Apt!',
#  'Sunlit Private Room   Spacious Pre War Apartment',
#  'Private Studio Apartment ',
#  'Appartement en duplex de 3 chambres',
#  'Fort Greene   Parlor One Bed',
#  'Bright, Spacious Wburg APT w  VIEW!',
#  'Comfy Rm, Hallway Bath, Forest Hills',
#  'Sleeps 4! Prime Chelsea~large 1BR',
#  'Large Spacious Room For Rent',
#  'Welcoming Park Slope Garden Apt.',
#  'Beautiful spacious bedroom',
#  "Livin' La Vida Brooklyn!!!",
#  'Attic Space   三楼阁楼',
#  'Double deck bed room 别墅二楼卧房',
#  'Beautiful, bright, quiet room w  private bathroom',
#  'Spacious neo country seaside loft',
#  '1st Time Solo Duo Travelers!Charming Studio Share!',
#  'cozy queen for 2 in el barrio',
#  'Prime Chelsea~XL1Br~Terrace~Sleeps4',
#  'Reno Studio Gramercy~Sleeps3!',
#  'Lovely   Spacious, Garden   Garden View',
#  'HEART of NEW YORK    ﾆｭｰﾖｰｸの中心',
#  'Spacious 2 Bedroom   Study',
#  'Sunny   spacious 1 bedroom gem!',
#  'Spacious 1BD in lovely Clinton Hill',
#  'Super Quiet, Private Patio',
#  'Spacious, rustic barn style bedroom',
#  '法拉盛中心温馨两房两厅公寓｡近一切｡2 br close to everything',
#  'Unique 2 Bed 2 Bath Duplex Apt',
#  'Spacious 2BR in UES   30 DAYS MIN',
#  'Cozy | Spacious | Great Location',
#  'Spacious Williamsburg Retreat',
#  'Skyline View Piano Room',
#  'Private Room w  Patio Near L Train!',
#  'Bright   quiet 2 bedroom brownstone',
#  'Spacious 1 Bedroom Apartment',
#  'Nirvana On Riverside',
#  'Clean | Green | Spacious\nWB BK Sanctuary! 2BR 2BA',
#  'Roomy sunny quiet fun great locale',
#  'Five star large one bedroom!',
#  'Private 1st level studio near NYC',
#  'Loft Studio Near UN Building 30 days min stay',
#  'Spacious Sunny Brooklyn Sanctuary',
#  'Brooklyn.  Room,  private bath   private entrance',
#  'Gorgeous quiet   central NYC apt!',
#  'Spacious,  3 bedrooms, 2 bath',
#  'Boutique Retreat',
#  'TOWNHOUSE NEAR RSD PARK    Spacious 2 Bedroom Apt',
#  'Great Spacious Appartment',
#  '汤母小屋',
#  'A hop to La Guardia Airport in quiet College Point',
#  'Spacious Private Room ',
#  'Charming Studio Apartment',
#  'Spacious 2 Bedroom, 2 Bath, 5th Avenue Entire Apt',
#  ' GALAXY  Spectacular 2 Bedroom   Spacious   Light!',
#  'Spacious Room at Broome St, LES',
#  'Modern Spacious 4BR  Tent Perfect for LARGE groups',
#  'Sunny, comfy room in quiet Park Slope apmt',
#  'Comfy Bedroom quite neighborhood ',
#  'LIC Super Sunny   Spacious 1BR Apt',
#  'Spacious, sunny, private loft bdrm!',
#  'Metro Retreat      Harlem',
#  'Spacious Luxury Condo 1 bedroom, NYC',
#  'Spacious East Village 1 Bedroom',
#  'Large Bohemian Studio  Gramercy!',
#  'Spacious Full 1 Bedroom Apartment',
#  'Unique NYC Loft   Guest Room',
#  'Spacious Private West Village Studio',
#  '纽约之家(Sunnyhome7)',
#  'Fabulous studio UES 30 days min',
#  'Charming sun drenched sanctuary',
#  'Cozy, quiet room near Central Park',
#  'Large Private Room in Spacious Apt',
#  'Union square~reno Studio~Terrace',
#  'Artist Musician Loft (HUGE space!)',
#  '“纽约之家 ”独立洗手间PrivateBathroom',
#  'clean, quiet, 1 bdrm, great locale',
#  'Spacious Private Room   Full Bath!',
#  'Sunny spacious private unit close CENTRAL PARK!',
#  'Chez Jesse Vacation Spot   Garden',
#  'Spacious 2 Story Apt. Near Subway',
#  'Spacious Bright West Village Apt!',
#  'Beautiful MASTER BEDROOM East side C7',
#  'Spacious Chique Brooklyn Gem',
#  'So clean so convenient.',
#  'Spacious UES 1 bedroom apartment',
#  'Park Slope center Garden Studio  ',
#  'Spacious, Renovated 1 BR Loft Apt',
#  'Sunny   Spacious Apt Near Subway',
#  'Lower East Side Studio !',
#  '“纽约之家” 独立洗手间PrivateBathroom',
#  'Spacious Private Room in Wash Hts!',
#  'Spacious bedroom in Oversized Apt.',
#  'Large private room on quiet street',
#  '❤️Lovely Historic Brownstone Charm❤️ LEGAL LISTING',
#  'one large private bedroom  two bedroom apartment',
#  '2 Flushing Sunny Garden View 舒适阳光房',
#  'Sunny, Spacious   Sweet 2BD home!',
#  'COLUMBIA PRESBYTERIAN MED CTR  AURA  Studio Apt',
#  'Spacious Studio',
#  'Private room in queens New York',
#  'Studio Apt East Harlem',
#  'Orchard Street Studio !',
#  'Quiet, quaint room in Victorian TH',
#  'Solo traveler oasis',
#  'Spacious Sunny Studio in LES',
#  'Modern Vibrant Large Cozy Bedroom  正面能量',
#  'Large  Room in Spacious Flat , Central  Location',
#  '近地铁及市中心,干净 NYC 30 min to Manhattan',
#  'Brooklyn Modern Spacious Studio',
#  'Colorful   Spacious near A Express',
#  'Cozy 1Br Apt❤️of Upper East Side near Central Park',
#  'Beautiful Condo w  Private Rooftop',
#  'Wburg 1 bedroom   Spacious   Sunny',
#  'Spacious, Peaceful Room',
#  'Casa de la Luna  Bedford Stuyvesant',
#  'Brooklyn Zen Gem Spacious Bedroom',
#  'Bright   Spacious',
#  'Upper West Side Spacious Home',
#  'Gramercy Studio w  Private Garden',
#  '⭐️Harlem getaway w  great amenities',
#  '3)Cozy Sunny Warm Room  阳光温馨单房 停车容易',
#  'Spacious quiet one bedroom apt',
#  'R S Modern Spacious Hideaway',
#  'Garden Parlor Apt   Fort Greene',
#  'Spacious Modern Contemp Living 2',
#  ' ESSENTIAL  Convenient Studio  Upper East Side!',
#  'ACADIA Spacious 2 Bedroom Apt   Close to Hospitals',
#  ' JAMES  Amazing Spacious 2 Bedroom  Bright!',
#  ' TERRA GARDEN  1 Bedroom Garden Apartment',
#  "♡Private Rm Women's Safe Art Home♡",
#  'Sunny   Spacious near Central Park',
#  'Flatiron Studio Loft, Elevator Bldg',
#  'A Spacious   Homelike Brooklyn Stay',
#  'Beautiful Spacious private studio',
#  'Spacious, Modern Times Square 3Bdrm      ',
#  '4 Bed, Duplex Garden Apt. on lovely, quiet block',
#  'spacious private rooms in 5bd 4bth',
#  'Renovated   Spacious Chelsea Studio',
#  'Wild Flower Nice quiet space Queen size bed.',
#  'Fort Greene Sanctuary',
#  'Small Studio Private Suite by the Park近公園新小套房,鬧中取靜',
#  'NiceRoomNiceNeighborhoodCloseMaimonidesHospital',
#  'светлая комната с балконом',
#  'Spacious two bedroom in NYC',
#  'Furnished quiet clean room',
#  'Spacious, Quiet One Bedroom Apt',
#  'Spacious Studio in Chelsea',
#  'Artist Musician Apartment, Bushwick',
#  'Putnam Garden  2BDR Garden Apt',
#  'Charming, quiet West Village studio',
#  'Charming 1 Bedroom Garden Apt!',
#  'Spacious Sunny Brownstone Room   Great Location!',
#  'Spacious cozy apartment',
#  'Your Spacious Home Away From Home!',
#  'Spacious 2BD near Prospect Park!',
#  'Share A Rustic Forte Greene studio w  adorable cat',
#  '❤️ Beautiful Artistic 2 Level Brownstone ❤️LEGAL❤️',
#  'home, sweet home : )  English, русский,  עברית',
#  'Spacious, Beautiful, Private Room',
#  'Comfy garden level room at Brooklyn Breakfast',
#  'Spacious park slope 2 bedroom',
#  'Charming studio apartment',
#  'Spacious bedroom',
#  'Modern • Sleek • Brooklyn',
#  'Spacious Chelsea Loft!',
#  'West Side Studio Apartment',
#  '★ Hidden Gem. Spacious. Restaurants, Cafés Galore.',
#  'Studio Close To LIJ, JFK.Private Entry,欢迎中国朋友来住',
#  'Tranquilo y soleado XL Bushwick loft w breakfast',
#  '纽约之家(PrivateBathroom4)',
#  '1 Bedroom Garden Apartment, Harlem',
#  'Spacious, Sunny   Clean, 1 bed, 1.5 bath Apt',
#  'Spacious Rooms near Barclays Center',
#  '纽约之家(SunnyHome6)',
#  'Sunny, spacious    35 mins Times Sq',
#  'Central Park Slope Garden Apt',
#  'Spacious Modern Alcove Studio 4',
#  'Spacious 1 BR Apartment   Sleeps 4',
#  'Room in 3BR Condo, FREE WASHER DRYER',
#  'Adorable, Artsy 1BR; Hip Location!',
#  'Spacious Ft. Greene room near subway restaurants',
#  'A Unique studio apartment',
#  'Charming Union Sq Studio w Elevator',
#  'Serene Private Room w  River View!',
#  'Doorman Gym Studio Deck!5155',
#  'Modern Southwestern Retreat  Spacious 1 Bed',
#  'Huge room in El Barrio.',
#  '2Bed  2Bath Impeccable Stylish Brooklyn Home',
#  'Huge New Reno Slick Times Sq Quiet!',
#  'Boutique Studio',
#  'Modern reno 2 room Times Sq quiet!',
#  'Reno huge 2 room quiet Times Sq!!!',
#  '❤️ Charming and Quiet NYC Guestroom ❤️',
#  "Huge NYC 4BR Condo ByD'subwaySlp 12",
#  'Modern Studio UWS',
#  'Mi Casa Es Su Casa NYC',
#  'Sunny, quiet place room 1',
#  'Beautiful Condo Prospect Heights',
#  'Brooklyn Best   Sunny Spacious Apt',
#  '❤️❤️Relaxing Guestroom by a Lovely Park ❤️❤️',
#  '2 Bedroom Private Garden Apartment',
#  'Entire Spacious Apt: LIMITED DATES',
#  'Spectacular Designer Loft',
#  'Super Quiet, Your Oasis',
#  'Unique Duplex Loft Private Roof',
#  'Sun drenched SoHo Duplex Loft',
#  'Spacious Williamsburg Beauty',
#  'Bright Spacious Brooklyn Gem, 3 BR',
#  'Spacious, Sunny,Beautiful Apartment',
#  '❤️ of Wburg, 2.5 Rms, Sep Entrances',
#  'Spacious Private 1 Bedroom Apartment',
#  'Clean Spacious Artsy Private Room',
#  'Madison Avenue Studio Suite (4)',
#  'Madison Avenue Studio Suite (3)',
#  'Spacious Beautiful Private Room',
#  'Spacious Private Brownstone Apt | 2 Bedroom',
#  'Spacious Large Private Room By Pr.  Park w Aircon',
#  'Madison Avenue Studio Suite (2)',
#  'Great studio near TIME SQUARE',
#  'Spacious 1 bed near TIME SQUARE',
#  'Spacious room in Brooklyn',
#  '位于曼哈顿纽约上城,高级住宅区',
#  'Prime East Village  Spacious',
#  'Prívate room in Queens, NY',
#  'Torre del Lago Room.',
#  '❤️FAB APT WITH PRIVATE GARDEN NEAR CENTRAL PARK!',
#  'NOLITA AMAZING Spacious!',
#  '纽约市曼哈顿中城East\xa052nd\xa0st_2室1厅_ 4500 月',
#  'Park Slope Garden Apartment',
#  'Ideal Brooklyn Location Spacious Bright 1 Bed',
#  'Sunlit   Spacious 2 Bedroom Brooklyn Apt',
#  'Spacious 2 Bedroom Lower East Side',
#  '纽约之家 (Sunny Home2)',
#  '纽约之家(Sunny Home1)',
#  'Doorman Studio Gym Deck!5108',
#  'Cute Spacious Williamsburg Apt',
#  'Tribeca Soho Garden Apartment',
#  'Spacious   Relaxing Garden Apartment',
#  'Beautiful designer studio on 1st',
#  'Fort Greene Studio Flat',
#  'Charming Spacious Park Slope Studio',
#  'Spacious Room in Park Slope',
#  'Studio Near Time Square',
#  'Bright, Spacious Alcove 1 Bedroom',
#  'Bright   Spacious living room',
#  'FT Greene Flat Private Entrance',
#  'Bright Spacious Luxury 1 BR',
#  'Private Spacious Room ~ Near Trains',
#  'Sage   Charming 2 Room Studio  7',
#  'Spacious, Private, Comfortable N. HARLEM Apartment',
#  'Doorman Studio Gym Rooftop 5170',
#  'Private Garden Apartment',
#  'Spacious park block garden studio',
#  'Dooman GYM prime location!5178',
#  'Sunny   Spacious 1br Lower East Side Apartment',
#  'Hudson COLUMBIA PRESBYTERIAN MED CTR   Studio Apt ',
#  'Brick House: Unique Garden Apartment! King Bed!',
#  '❤️PRIVATE ROOM❤️ Female guest only',
#  'Spacious West Village Studio Apt',
#  'Private studio apartment',
#  'Beautiful, light filled, spacious',
#  'Park Avenue Studio Suite',
#  'CHIC STUDIOS ON E 54TH~PRIME LOCATION~SUTTON PLACE',
#  'Spacious Art Duplex: 4 Full Beds   3 BR   3 Bath',
#  'Spacious 2bd Condo w  Private Patio',
#  '与众不同,方便停车｡值得一试!',
#  'Spacious 1 BR Upper East Side',
#  'Spacious 1 BDRM near Central Park',
#  'Spacious, Artsy Room!',
#  'Spacious Bright   Clean Studio Near Central Park',
#  'Spacious Harlem Brownstone apartment',
#  'Cozy, quiet, studio apartment',
#  'UES area ,Luxury modern quiet private Apt',
#  'Spacious Studio Apartment',
#  'Modern 1BR apt  prime Times Square location!!',
#  'SoBro Guest House',
#  'Spacious Parkside Abode',
#  'Spacious 2 bedroom Garden apartment',
#  'Zen room at Casa de la Luna',
#  'Buck room at Casa de la Luna',
#  'Beautiful spacious bedroom BayRidge FEMALES only',
#  'New   Bright Garden Apartment',
#  'Sunny, Spacious, Parkside Room!',
#  'Bright  Studio Near Time Square',
#  'Studio Near Time Square',
#  'Spacious Studio w  Patio  Ft Greene',
#  '旅途中的家',
#  'Spacious Williamsburg Apartment',
#  'Sun drenched Park Slope Studio',
#  'Spacious 3 Bedroom in Park Slope',
#  'Your Hudson Heights Hideaway ◔‿◔',
#  'Clean   Spacious Bushwick Loft (front)',
#  'Acogedora  habitación en el corazón de Manhattan',
#  'Sun Drenched Studio',
#  'Amazing light, spacious   Modern',
#  'Private room w  lush garden quiet area',
#  'Private Parkside Room',
#  'Stunning, spacious apt near nightlife   parks!',
#  'Studio near Time Square',
#  'Spacious 2 bedroom apartment',
#  'Spacious 1 bedroom 1 bath',
#  'Garden level studio w backyard',
#  'Unique 2BR Apartment',
#  'Central Park Bedroom   Spacious, Sunny, Subway',
#  'Spacious 1 BR Apartment w  private backyard',
#  'Beautiful  En suit',
#  'Massive Bedroom Prime Flatiron Location',
#  'Spacious bushwick brownstone',
#  'Fab Studio Apt Nr Barclays Centre Off Road Parking',
#  'Bright   spacious Room in Harlem',
#  'Garden level apartment in Bed Stuy',
#  '1st Time Solo Guests: Charming NYC Apt. Share!!!',
#  'Large deluxe queen size bedroom',
#  'Sunny   Spacious 1bdrm apt',
#  'Spacious   Quiet Brooklyn Carriage House',
#  'Beautiful Spacious Apartment near Prospect Park',
#  'Spacious East 39th Street Furnished Studio',
#  'Cozy Spacious Double Bed  2A Near JFK   J Train',
#  'Beautiful  studio apt. near Hudson River Park!!',
#  'Private Condo Room w  Patio',
#  'Airy, Private, Spacious   Accessible',
#  'Spacious, Bright, Private NYC',
#  'Cozy BR in large quiet EV apt',
#  'West 74th Street, Svcd Studio Apartment',
#  'Spacious Comfortable Room Located In East Flatbush',
#  'Convenient   Spacious Place in Brooklyn, NYC',
#  'Beautiful Spacious 3 BR Cosy Apt.',
#  'Planta Baja Studio',
#  'Spacious room in Astoria',
#  'NYC   Luxury, quiet, safe well located',
#  'Brooklyn Room, Calm Spacious Oasis, Prospect Park',
#  'Beautiful   Spacious Studio Near Central Park',
#  'Spacious Studio Apartment',
#  'Private Micro Room 3',
#  'Modern bright spacious duplex apartment',
#  'Private Micro Room  1',
#  'Beautiful two bedroom apartment in Astoria queens!',
#  'LEGO Garden 1BR Apt  Patio near JFK   LGA Airports',
#  'Spacious Bushwick Room w  Private Entrance   Bath',
#  'Private Micro Room 2',
#  'Deluxe Furnished Spacious Studio Apartment',
#  'Spacious Harlem Garden Apartment',
#  'Vida Local',
#  'Spacious master bedroom in Forest Hills',
#  'Great quiet room,great location',
#  'Best Location   Modern 1 BR, very quiet',
#  '纽约之家(Sunny Home4)',
#  'Spacious Room in Central Location',
#  'Great Studio near Time Square',
#  'Private   Spacious Master Suite w  Full Bath',
#  'Gorgeous studio Near Time Square',
#  'B crownheights queen size bed 100',
#  'Spacious Prospect Park Garden Apt',
#  'Spacious room in Prospect Park',
#  'Doorman GYM Studio Best Location 5193',
#  'Spacious bedroom in Inwood',
#  'New Building Spacious 2 bed 2 bath  E. Harlem!',
#  'Charming, Spacious 2 Bedroom on UWS',
#  'Spacious   Clean Apartment   Patio. Close to metro',
#  'Beautiful, Spacious Studio In VERY Convenient Area',
#  'Park Avenue Studio Suite (3)',
#  'Spacious 1 bedroom in loft style building',
#  '(Room201)7分钟拉瓜迪机场,19分钟肯尼迪机场｡皇后区法拉盛中心,地段超好｡ 201',
#  'Spacious Brooklyn Apartment',
#  'Forest Hills',
#  'Location Location   Spacious Room in Time Square',
#  'Designer Basement Apt by the Park 新精緻近公園舒適含窗半地下公寓',
#  'Double Twin Spacious Room In Small',
#  'Private Suite · Sparkling Clean · Memory Foam',
#  '纽约之家(SunnyHome5)',
#  'Central Park Slope Garden Apartment',
#  'Beautiful loft apt. on quiet Bed Stuy block',
#  'Private Large Studio size Room',
#  'Studio Apartment Prospect Heights',
#  '21St 6Th Ave Prime Doorman 1bed !GYM 5204',
#  'Relaxing, spacious, private room Riverside Drive',
#  'Modern Spacious Private One bedroom Free Parking.',
#  '纽约之家(SunnyHome3)',
#  'BEACH BLOCK IN ♡ OF ROCKAWAY, NYC',
#  'Spacious 3 Bedroom Apartment Near Prospect Park',
#  'Nice Private room in quiet 2 level Brownstone!',
#  'East Harlem: Spacious 3BR',
#  'Prívate Cozy Room',
#  'Spacious Bedroom in TriBeCa',
#  'Beautiful, quiet, light filled 1 bdrm apt',
#  'New york Multi unit building',
#  'Bright, Modern, Clean, Spacious, Brooklyn Home',
#  'Immaculate   Spacious Home   Astoria, Queens',
#  'Union Square   Interior designer   Private 1 bdr',
#  'Executive Studio Best Location',
#  'Le Petit Palace De Brooklyn   Clean Comfy 4 BR Apt',
#  'Charming 1 Bedroom Garden Apt',
#  'EPIC VIEWS ❤️ Wyndham Midtown 45 at NYC Studio ❤️',
#  'Spacious Room in IDEAL LES LOCATION',
#  'Private, Spacious Bedroom in Harlem, single bed',
#  'Beautiful BR in quiet Greenpoint',
#  'Film   photography location in unique apartment',
#  'Hip quiet',
#  'BedStuy Beautiful Spacious Garden Apartment',
#  'Beautiful room in Spacious Duplex',
#  'Spacious Victorian home',
#  'Spacious Brooklyn Loft Apartment   Rooftop Deck',
#  'Hudson Yards Chelsea  ️',
#  '豪华套间',
#  'Cozy Home in Harlem ✨',
#  'Jefferson Estates',
#  'Beautiful Bedroom: Spacious   Sunny!',
#  'Ponerse las Pilas   VIVO NYC!!!',
#  '❤️ Beautiful Spacious Convenient BK Apartment!',
#  'A beautiful comfy   spacious room.',
#  'Modern, Ambient 1 Bedroom Apartment',
#  'Gorgeous Spacious Bedroom In Ridgewood Queens',
#  'Delightful studio apartment.',
#  'Affordable Private Spacious Room in Brooklyn',
#  'Charming Fort Greene Apartment',
#  'Spacious   Sunny 1 Bedroom Gramercy Flatiron Apt',
#  'Modern, Spacious   Pristine Room in Gramercy',
#  'Perfect Location! Spacious Upper West Side Flat',
#  'Evergreen Upper Bed for Female Traveler 紐約民宿',
#  'NYC  ✰ Prime Williamsburg ✰  w  Private Patio',
#  '❤️ POSH NYC RESORT   Midtown 45   2 Guests ❤️',
#  'Cozy Room In Williamsburg Near Trains❤️',
#  'Spacious, quiet 1 br apt in beautiful Inwood!',
#  'FLUSHING 停车方便｡是你入住的最好选择｡',
#  'home away from home : ) English, русский, עברית',
#  'HUGE Private Room, Doorman Building, quiet !',
#  'Peaches Paradise.',
#  'Spacious sun lit Bushwick room',
#  'Micro Room A',
#  'Stylish   Spacious Apartment',
#  'Cozy, Quiet, 1 bedroom apartment   Lower East Side',
#  'Sun Drenched Spacious Loft in NYCs Trendiest Hood',
#  '2 blocks to 2 ⭐️⭐️⭐️⭐️⭐️',
#  'Spacious Brooklyn, New York Retreat',
#  'Big Bright Room ☼ Lower East Side',
#  'Spacious bedroom',
#  'Modern, Beautiful Tribeca 2 Bedroom Loft',
#  '❤️❤️❤️ COZY Place by the Park for ONE ❤️❤️❤️',
#  'Spacious Bedroom   Convinience',
#  'Huge Fort Greene Loft, Prime!',
#  'Spacious apartment in delightful Cobble Hill',
#  '1 private room in a spacious quiet Park Slope apt',
#  'Park Avenue South, Svcd Studio Apt',
#  'Charming   Modern, Comfortable   Efficient 1 BR',
#  'Large Studio New York Bronx comfortable',
#  'NYで人気の街ﾌﾞﾙｯｸﾘﾝﾊﾟｰｸｽﾛｰﾌﾟで､暮らしてみませんか｡',
#  '2 bed spacious Quiet Upper Ditmars Astoria Wifi.',
#  'Spacious Studio in E Flatbush',
#  'Private delightful   calming  Brownstone Room',
#  '法拉盛summer家(C)closed to JFK LGA Citi Field Parking',
#  'Bright   Spacious Chelsea Studio',
#  'Contemporary. Spacious Apartment. Close to Ferry.',
#  'Essex House Historic Condo hotel',
#  '法拉盛summer家(B)closed to JFK LGA Citi Field parking',
#  'Spacious Brownstone  1Bd',
#  'Spacious beautiful bedroom:)',
#  'Spacious, Private 2 BR , 4 Bathrooms in Brooklyn',
#  'HUGE 1BR Apt, Varrazano promenade,night life  More',
#  '简单的四房一厅两卫生间,位于北上远离开辆,走路四分钟到地铁站,交通便利\nSimple bigroom',
#  '2fireplcs,Garden,BBQ,wshr dryer,JacuzTub,BIG Kitch',
#  'NANCY clean quiet very close city',
#  'Spacious 2 BR Bedford Stuyvesant Bklyn NY',
#  ' SPECIAL \nCOZY WATERFRONT APARTMENT \n•SUPERHOST•',
#  'Unique Prime Location NYC  Sleeps 6',
#  'Spacious Room w  2 Bed',
#  'Sun drenched Park Slope getaway..',
#  'Dreamy Parkside Loft Studio w  Private Patio',
#  'Adorable Bright Private Bedroom.',
#  'Bayside Room  w  1 Bed',
#  'Great room in a spacious Inwood Apartment',
#  'Spacious Luxury Loft   1BR',
#  'Bayside Room w  2 Bed',
#  'Shang Ri La Studio',
#  'Spacious 2 bedroom w  balcony. BrooklynNY NEAR ALL',
#  'Nice room in  quiet 3BR apartment',
#  'PRIVATE ROOM near JFK   La Guardia',
#  'Greenpoint, BK 1 Bedroom, Couple Solo Traveler',
#  'Nice private room in quiet E Village apt',
#  'Spacious Garden Apartment Private Entrance',
#  'Spacious quiet garden 1 Br   Sunny Back Yard',
#  'Big, Bright, Tribeca Studio w  Doorman   Elevator',
#  'South Bronx Piano District artist Loft ',
#  '⭐️Walk   Transit Score 97⭐️8min to Yankee Std⭐️',
#  '《1》法拉盛市中心明亮干净的私人房间',
#  '温馨舒适双人房,双床,明亮大窗,电梯公寓(两个房间用一个卫生间)',
#  'Inspiring   Motivational ⭐️',
#  'Great Studio Near Time Square',
#  'Spacious Studio ( W 48 street )',
#  'Spacious Apt w Deck, Williamsburg',
#  'Fresh, bright modern studio w  Garage Parking',
#  '《2》法拉盛市中心明亮干净的私人房间',
#  "☆☆☆Perfect Couple's Getaway☆☆☆",
#  '☆☆☆Authentic NYC Experience☆☆☆',
#  "☆☆☆Luxurious Couple's Retreat☆☆☆",
#  'Spacious Studio in Hamilton Heights',
#  'NYC Hells Kitchen 51St ﾐｯﾄﾞﾀｳﾝｳｴｽﾄｻｲﾄﾞ',
#  'Spacious 2 Bedroom Apartment Near Central Park',
#  'Spacious 2 bedrooms Loft in Brooklyn',
#  'Spacious Greenpoint Apt near McGolrick Park!',
#  'Spacious private room close St. Barnabas Hospital',
#  'West 74th Street, Svcd Studio Apartment',
#  'Casa Estrella',
#  'Central Park north spacious residence',
#  'Manhattan  sofa bed, private room, no deposit',
#  'PRIME WILLIAMSBURG  Spacious 4BR Bohemian Oasis',
#  'Spacious 2bed private rm close St.BarnabasHospital',
#  'Big room in Queens, close to all 皇后区大房, 近超市､地铁',
#  'Stylish Park Slope loft',
#  'Spacious Ocean Side Studio in\nBrooklyn w Parking',
#  '法拉盛中心公寓楼高层',
#  '3Beds Kitchen wifi US Open唐人街电梯公寓 厨卫 网快 美网赛事',
#  'Studio apartment near Columbus Circle Central Park',
#  'Spacious, Quiet, Cozy Art Filled Chelsea Apartment',
#  'Basic place :) Forest Hills Rego Park',
#  'Bonito dormitorio 20 25 minutos Times Square.',
#  'Spacious 5th Ave   Semi Pvt Bed   Bath',
#  '纽约干净大房近地铁站',
#  'Habitación ideal para viajeros',
#  'Large Bright Studio Apartment',
#  'Scenic   quiet Apt   Windsor Terrace Prospect Park',
#  'Heart Of Queens 2❤️❤️  Jackson Heights  Elmhurst',
#  'Beautiful brownstone apartment on quiet street',
#  'Relaxing Room in a Spacious Artist Apartment',
#  'Room in a Beautiful, Spacious Home',
#  'Private room in midtown Manhattan曼哈顿中心 位于地狱厨房,位置棒棒',
#  'All Yours! Entire Spacious Bright Modern Loft!',
#  'Beautiful Spacious 1 Bedroom Apt. in New York City',
#  'ღღღUltimate Broadway Experienceღღღ',
#  'ღღღSteps to Major Tourist Attractionsღღღ',
#  'A light spacious adorable room in Brooklyn',
#  '法拉盛(Flushing)独立出入Basement套房出租｡2房1卫 2Rooms 1Bath',
#  'Habitación ubicada céntricamente en la ciudad.',
#  'LES East Village Spacious Getaway',
#  '纽约三室一厅两全浴带独立厨房和停车位\nThree Room Two Bath and Parking',
#  'Spacious 2 bedroom railroad apartment',
#  'Good Vibes Tribeca Loft',
#  'Brooklyn Spacious Studio',
#  'Spacious Prospect Park Loft Apartment',
#  'Gorgeous Sun fulled Studio, Perfect Location!!!',
#  'Modern, Stylish   Spacious Brooklyn Oasis',
#  'Dungeon heaven. SOHO loft feel in Bklyn.❤️❤️❤️❤️❤️',
#  'Spacious Clean Studio  Apartment',
#  'Spacious   Spectacular',
#  'Private Room Spacious Apartment UES Spanish Harlem',
#  'Mi Casa su Casa!',
#  '❤️Private Suite w Balcony ❤️25 Mins to NYC',
#  'Spacious 3 BDR APT Brooklyn Sleeps 12!',
#  'Spacious, Airy, Private Bedroom',
#  '¡AMAZING PENTHOUSE IN SOHO (Nolita 1BR)!',
#  'Spacious 2 BDR APT BROOKLYN Sleeps 8!',
#  'Spacious Room in Modern Duplex Loft',
#  'Spacious 2 bedroom apartment',
#  'Loring Estate',
#  '近JFK 机场和地铁',
#  'Spacious private room near central park',
#  'Spacious 1BR near park   subways',
#  'Spacious bedroom w  private entrance   roofdeck',
#  'Time Square   Central Park Condo Sleeps6',
#  'Large and in charge: pvt "dungeon" apt. ❤️❤️❤️❤️❤️',
#  'Entire PVT 3BR townhouse apt, Brooklyn.❤️❤️❤️❤️❤️',
#  'Light Filled Top Floor of 4BR Townhouse.❤️❤️❤️❤️❤️',
#  'Star Labs',
#  'Spacious One Bedroom in Bed Stuy',
#  'Spacious Brooklyn home 2bdrm near Prospect Park.',
#  'Quiet,Comfy Spacious Room near F G train',
#  'Quiet,Comfy Spacious Room near F G train',
#  'Great spacious prime studio in Midtown',
#  'Spacious 1 bed 1 bath home, 3A',
#  'Spacious Home In South Brooklyn',
#  'Spacious Chelsea Condo MUST SEE',
#  'Large Studio near Central Park',
#  '5Star Super Convenient   Spacious BR, 1st Flr Apt',
#  'Modern, Quiet   Ultra Clean 1 BDRM Steps Subway',
#  '❤️Quiet room w PRIVATE BATHROOM near Manhattan!⭐️',
#  'Spacious Modern King size living space   Bedroom',
#  '️CENTRALLY LOCATED️  Great for Families   Groups',
#  '☺Kinda feels JUST LIKE HOME! ☺ [BEST RATE]',
#  '旅客之家',
#  'IN MINT CONDITION STUDIOS EAST 44TH UNITED NATIONS',
#  'Charming, Spacious Private Room in Harlem, NYC',
#  'Superhost Sunny Private room in 2BR ❤️Williamsburg',
#  'IN MINT CONDITION STUDIOS EAST 44TH UNITED NATIONS',
#  'IN MINT CONDITION STUDIOS EAST 44TH UNITED NATIONS',
#  'IN MINT CONDITION STUDIOS EAST 44TH UNITED NATIONS',
#  'IN MINT CONDITION STUDIOS EAST 44TH UNITED NATIONS',
#  'IN MINT CONDITION STUDIOS EAST 44TH UNITED NATIONS',
#  'Basin Homes',
#  'Spacious Split Level  Apartment',
#  'HI END LIVING IN UES LUXURY CONDOS EAST 80TH ST',
#  '2017 Renovated Central Flushing, NYC法拉盛中心的新装修房Wifi',
#  'Oversized Studio Flat',
#  'Prime Location of Flushing Queens 豪华卧室 旅途中的家 A',
#  '汤姆公寓',
#  'Spacious Bedroom near Prospect Park',
#  'Spacious NYC Duplex  1 Bedroom   2 Bathrooms',
#  '天使的温暖',
#  'Prime Location of Flushing Queens 豪华卧室 旅途中的家 B',
#  'Sunny spacious convenient private room   Bushwick!',
#  'Prime Location of Flushing Queens 豪华卧室 旅途中的家 C',
#  'Casa Blue',
#  'Prime Location of Flushing Queens 豪华卧室 旅途中的家 D',
#  'SOHO   GREENWICH VILLAGE\nPrime location  1 Bedroom',
#  '♛ Fabulous Bedroom |★★★★★| ♛',
#  'Brand new, comfortable, refined, our first!全新,商务最佳',
#  'Red Hook Garden Apartment',
#  '温馨双人房,步行地铁两分钟,',
#  'Large Private Room In Spacious Guest House',
#  'Spacious room near Times Square',
#  'Feng Shui Private Room In Brooklyn',
#  ' 2,单间双人房,(共用卫生间)',
#  '大双人房,共用卫生间,',
#  'Beautiful   Spacious Private Brooklyn Loft',
#  'Roomy bedroom in Spacious Chelsea Loft!',
#  'Large Studio 7 Guests',
#  'Welcome! A spacious room close to subway station',
#  'Spacious very clean professional service  PK SLOPE',
#  'NYﾐｯﾄﾞﾀｳﾝ高級ｺﾝﾄﾞのﾘﾋﾞﾝｸﾞﾙｰﾑに宿泊',
#  'A M Spacious Home Away For Vacationers—NYC',
#  'Heart of Queens 3 ❤️❤️❤️Private Bath Jackson Hgts',
#  'La Casa de Ishmael',
#  'Spacious Brooklyn Brownstone Apt.',
#  'Spacious Duplex Loft Apt, Dtwn Bklyn, Near TRAINS',
#  'Villa Borghese',
#  'Beautiful Room in Bushwick, Bk. (Hablo Español)',
#  'Spacious, Cozy   Quiet Chelsea Designer Apartment',
#  '露西套房(Lucy Apt.)',
#  'Clean   quiet home on quiet block',
#  'Alluring Private Bedroom in Spacious UWS Apt',
#  'Spacious   Bright Brooklyn Apartment',
#  'Charming, cozy, clean, affordable   spacious room',
#  'Habitacion Privada',
#  'Fabulous, Spacious Studio by CP. An Artful Retreat',
#  '佳源家庭旅馆',
#  '佳源家庭旅馆套房',
#  'Spacious 1 bedroom Apartment w  2 beds',
#  'Large, beautiful and elegant, clean studio舒适洁净的保证',
#  'Spacious Private bedroom   private bathroom',
#  'Sunny Spacious Modern Designer Apartment',
#  '纽约森林小丘简约文艺客舍',
#  '佳源家庭旅馆双床房间',
#  'Spacious   Homey Williamsburg 1BR Apartment',
#  'Prime Tribeca Loft',
#  'Комната. Место в комнате',
#  'LA COURONNE   Sophisticated Spacious 3 BDRM 2 BTHS',
#  '阳光之家',
#  'Private Room in Spacious Chelsea Loft',
#  'Lower East Side Studio Escape  4',
#  'Комната для пары',
#  'Furnished spacious  NYC studio',
#  'One nice room on the Roosevelt Island; 罗岛一间卧室出租',
#  'Ideal Stay in NYC! ☆☆☆☆☆',
#  '3 Bedroom Prime Park Slope 6th Ave Barclays Center',
#  'Perfect, Private Garden Apartment (Prime Brooklyn)',
#  'Private   Comfortable Room in a quiet neighborhood',
#  'Spacious light room in a cool neighborhood',
#  "Casa de Compri Int'l",
#  'Studio, Best Location near Columbus Circle',
#  '2000呎 法拉盛美丽豪华大套房',
#  'Fort Greene Loft',
#  'Tudor City',
#  'Bright large studio loft, 100  private, Bushwick',
#  '法拉盛唯美独立房间',
#  '法拉盛温馨亲子房',
#  '法拉盛高档,奢华大套房(带按摩浴缸和淋浴的独立卫生间)',
#  'Spacious, Modern Two Bedroom, Two Bath in Harlem',
#  '溫馨大套房',
#  'Cool Out Private large ensuite nearJFK sleeps 4',
#  'Spacious Prospect Park Studio',
#  'Sun   Central Park',
#  'Spacious Family Space   2 Bedrooms',
#  'Comfy   quiet 1 BR   East Williamsburg',
#  'Ditmas park lot',
#  'East Williamsburg’s Spacious Sun drenched Apt.',
#  'Spacious Studio In Queens',
#  '纽约曼哈顿 唐人街公寓   方便,性价比高',
#  'Sunny Williamsburg Style in Prime Location ❤️',
#  '(☆☆☆☆☆) New ultra modern 1 bedroom apartment',
#  'Spacious Brooklyn loft in Clinton Hill',
#  '•HEART OF WILLIAMSBURG APARTMENT COZY PRIVATE•',
#  '•COZY APARTMENT 5 MINS TO MANHATTAN•',
#  'Stylish   Spacious 1BD in Central Harlem!',
#  'Private Room B In Prime Location',
#  'Private Room C In Prime Location',
#  'Ft Greene Studio',
#  'New Private studio apartment',
#  '(Room 102)法拉盛舒适轻奢套房',
#  'Greenpoint Sun Garden',
#  'Bushwick BedStuy Studio Apartment',
#  'Bright Brooklyn garden level apartment',
#  'Studio apartment  PRIVATE',
#  '★Spacious 2 b r apt | 3 beds   WiFi~Sleeps 1 6★',
#  'Yoga   sauna during your stay, spacious   sunny.',
#  'Fort Greene Jewel',
#  '法拉盛中心近地铁舒适单房—Cozy room in flushing',
#  'Premier Garden Suite near Columbia University',
#  'crème de la crème    Luxurious 1 BR Grand Central',
#  '•COZY APARTMENT IN BEDFORD AREA, 5 MINS MANHATTAN•',
#  'Prívate room',
#  'Comfortable Studio Apartment!',
#  'Habitación comoda',
#  'Lincon appartament',
#  'Bright Spacious Private Room  30 min NYC',
#  'Spacious King size Apartment near Prospect Park',
#  'My Casa es su Casa!',
#  'Spacious Room in Prime Prospect Heights, Brooklyn',
#  'Habitacion de renta para 2',
#  'Apartamento muy acogedor en Manhattan',
#  'Indo Sweet',
#  'HUGE studio apartment near ALL!',
#  'Private Room A In Prime Location',
#  'solo pueden reservar  mujeres, es casa de familia.',
#  'Spacious garden level 1BR in Bed Stuy brownstone',
#  'Mi hermoso hogar a 4 bloques del AirPort LGA',
#  'Unique   Spacious, W Village. 1 Bdrm. NEW LISTING!',
#  '••RARE Modern Apt For 2019 Next to Subway   JFK••',
#  'Spacious 2 level home for Groups sleeps upto 12',
#  'Spacious   bright 2BR 2BA (available for August)',
#  'La Quinta Central Park West Hotel',
#  'Inspiring   Tranquil Experience',
#  'Sun drenched Artist Loft',
#  'Luxurious 2 Story Home • Large Terrace • Views',
#  'Private Clean, Spacious Room in West Harlem!',
#  '2 Bed 2 Bath, spacious, modern   bright!',
#  'Light drenched 2 bedroom apt, prime location中国城',
#  'Friendly, quiet Brooklyn Heights Apartment',
#  'Gabby Suite  in the Heights\nSe habla Español',
#  'Prime Location 3 Bedrroms Apartment',
#  'Cuarto para 3',
#  'Apto En la exclusiva zona Austin St, Forest Hills',
#  'Garden Apartment',
#  'La Quinta Central Park West',
#  ' Prime East Village  Quiet   Spacious 2BR Flat',
#  'Astoria Prime',
#  'Flushing 旅游,探亲,留学生首选 private bedrm, bath, livingrm',
#  'Bright, super spacious 1.5 bedroom apt',
#  'Spacious East village apartment',
#  'Spacious 1 Bedroom in TriBeCa',
#  'Sunny, Spacious Bed Stuy Dream Apartment',
#  'Private Studio in charming Tudor style home.',
#  '温馨小屋',
#  ' 1  Spacious Private Room',
#  'Private room in Manhattan(2名個室)',
#  'Beautiful sunlit spacious loft like pvt. bedroom!',
#  'Beautiful Spacious  Studio Apartment',
#  '⭐︎⭐︎PRIVATE Bathroom⭐︎⭐︎2min to subway huge living',
#  'Tranquil private bedroom, Hamilton Heights, NY',
#  'Paradise   comfortable, spacious loft apartment',
#  'Cozy Private Room in Flushing 法拉盛中心單人房间',
#  'Spacious 1st floor apartment.',
#  '5 Star Quiet, Spacious Condo. Freedom Tower view',
#  'new entire condo, terrace, parking D N R trains IC',
#  'Cozy Private Room in Downtown Flushing法拉盛中心私人房间',
#  'Sunny Bedroom with Private Bathroom 法拉盛中心私人房間獨立衛浴',
#  'Stunning spacious study private bedroom  4',
#  '2 Bedroom Modern Contempo Bright Apartment',
#  '••Cozy Em’s place••',
#  'Good Vibes private room',
#  'Spacious, Charming 2BR Apt in Trendy Bushwick',
#  'Spacious Room',
#  '"San Paraíso" 80s curated Retro 3 Bedroom LES Pad',
#  'Spacious Apartment in Brooklyn',
#  'Modern   Spacious Apartment in Central Harlem',
#  'Bedroom Casa Alvarez',
#  'две кровати в комнате',
#  'Wall Street Luxuriuos apartment Financial District',
#  'Comfortable,Spacious,clean Private Room',
#  'prime upper west Cozy Studio deal',
#  'summer(A套房私享一层closed to JFK LGA Citi Field parking',
#  'Angie Suite  in the Heights\nSe habla Español',
#  'Sisters Suite in theHeights\nSe habla Español',
#  'Spacious sunlit room in Astoria',
#  'New Condo 2 bedrms  1,5bath elevator   balcony',
#  'Two Bridges Private Escape',
#  'Beautiful, spacious Upper West Side 1Br apartment',
#  'Sunny, Spacious,   Clean East Village One Bedroom!',
#  'Spacious Private Basement Apartment',
#  'El jardín del Edén',
#  'Room B Close to NYU Langone H Metro station',
#  'Financial District  Private Room',
#  'Spacious Private Room in Brooklyn',
#  'Spacious Bedroom in Unique Williamsburg',
#  '✴SPACIOUS HOMEY✴ 2 BD Sleeps 6! Brooklyn NY',
#  'Hiéroglyphe',
#  'Art双层屋',
#  '新一处客居(New place 1)',
#  '新一处客居(Newplace2)',
#  '新一处客居(New place3)',
#  ...]

# %% [markdown]
# Now we will turn these into empty string lists so when the sentiment analysis is performed, a score of 0 will be obtained.

# %%
for i in desc.index:
    if desc[i] in not_en:
        desc[i] = ''

# %% [markdown]
# Now removing stop words

# %%
description = desc.apply(stop_words)
description
# Out:
# 0                          [Clean, quiet, apt, home, park]
# 1                                [Skylit, Midtown, Castle]
# 2                [THE, VILLAGE, OF, HARLEM, .NEW, YORK, !]
# 3                        [Cozy, Entire, Floor, Brownstone]
# 5        [Large, Cozy, 1, BR, Apartment, In, Midtown, E...
#                                ...
# 48890    [Charming, one, bedroom, newly, renovated, row...
# 48891     [Affordable, room, Bushwick, East, Williamsburg]
# 48892            [Sunny, Studio, Historical, Neighborhood]
# 48893         [43rd, St., Time, Square, cozy, single, bed]
# 48894           [Trendy, duplex, heart, Hell, 's, Kitchen]
# Name: name, Length: 31362, dtype: object

# %% [markdown]
# To use VADER, we have to put our names into a single string

# %%
# creating a function to convert a list of strings to single string
def to_single_string(list_of_strings):
    result = ''
    for string in list_of_strings:
        result += ' ' +string
    return result

# applying above function
description = description.apply(to_single_string)
description
# Out:
# 0                             Clean quiet apt home park
# 1                                 Skylit Midtown Castle
# 2                     THE VILLAGE OF HARLEM .NEW YORK !
# 3                          Cozy Entire Floor Brownstone
# 5             Large Cozy 1 BR Apartment In Midtown East
#                               ...
# 48890     Charming one bedroom newly renovated rowhouse
# 48891        Affordable room Bushwick East Williamsburg
# 48892              Sunny Studio Historical Neighborhood
# 48893              43rd St. Time Square cozy single bed
# 48894               Trendy duplex heart Hell 's Kitchen
# Name: name, Length: 31362, dtype: object

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

sentiment_analyzer = SentimentIntensityAnalyzer()

def sentiment_score(string):
        result = sentiment_analyzer.polarity_scores(string)
        return result

# %%
sentiment = description.apply(sentiment_score)
sentiment
# Out:
# 0        {'neg': 0.0, 'neu': 0.597, 'pos': 0.403, 'comp...
# 1        {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2        {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3        {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 5        {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#                                ...
# 48890    {'neg': 0.0, 'neu': 0.568, 'pos': 0.432, 'comp...
# 48891    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 48892    {'neg': 0.0, 'neu': 0.517, 'pos': 0.483, 'comp...
# 48893    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 48894    {'neg': 0.359, 'neu': 0.312, 'pos': 0.328, 'co...
# Name: name, Length: 31362, dtype: object

# %% [markdown]
# VADER uses 4 main metrics to measure sentiment for words. Positive, negative, and neutral represent the proportion of text falling into these categories. The last metric is a sum of all the lexicon ratings that have been normalized between -1 (for most negative) to +1 (for most positive). A general rule is:
# 1. *positive sentiment*: compound score >= 0.05
# 2. *neutral sentiment*: -0.05 < compound score < 0.05
# 3. *negative sentiment*: compound score <= -0.05
#
# Simply to experiment, I will try two different sentiment scoring methods:
# 1. sentiment value = compound score
# 2. sentiment value = {-1, 0 ,1} depending on polarity of the sentiment from the ranges above

# %%
# method 1
def compound_score(sent):
    return sent.get('compound')

sentiment_M1 = sentiment.apply(compound_score)
sentiment_M1
# Out:
# 0        0.4019
# 1        0.0000
# 2        0.0000
# 3        0.0000
# 5        0.0000
#           ...
# 48890    0.5859
# 48891    0.0000
# 48892    0.4215
# 48893    0.0000
# 48894   -0.1027
# Name: name, Length: 31362, dtype: float64

# %%
# method 2
def polarity(sent):
    compound = sent.get('compound')
    if(compound >= 0.05):
        return 1
    elif(compound <= -0.05):
        return -1
    return 0

sentiment_M2 = sentiment.apply(polarity)
sentiment_M2
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 5        0
#         ..
# 48890    1
# 48891    0
# 48892    1
# 48893    0
# 48894   -1
# Name: name, Length: 31362, dtype: int64

# %% [markdown]
# Now that we obtained the sentiment scores for the english titles, we have to obtain the average in each neighborhood and apply that average as the sentiment values for the non-english titles.

# %%
df.columns
# Out:
# Index(['name', 'neighbourhood_group', 'neighbourhood', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# creating temporary df
temporary = pd.DataFrame()
temporary['location'] = df['neighbourhood']
temporary['sent_M1'] = sentiment_M1.to_frame()
temporary['sent_M2'] = sentiment_M2.to_frame()
temporary['name'] = description.to_frame()
temporary
# Out:
#                  location  sent_M1  sent_M2  \
# 0              Kensington   0.4019        1
# 1                 Midtown   0.0000        0
# 2                  Harlem   0.0000        0
# 3            Clinton Hill   0.0000        0
# 5             Murray Hill   0.0000        0
# ...                   ...      ...      ...
# 48890  Bedford-Stuyvesant   0.5859        1
# 48891            Bushwick   0.0000        0
# 48892              Harlem   0.4215        1
# 48893      Hell's Kitchen   0.0000        0
# 48894      Hell's Kitchen  -0.1027       -1
#
#                                                  name
# 0                           Clean quiet apt home park
# 1                               Skylit Midtown Castle
# 2                   THE VILLAGE OF HARLEM .NEW YORK !
# 3                        Cozy Entire Floor Brownstone
# 5           Large Cozy 1 BR Apartment In Midtown East
# ...                                               ...
# 48890   Charming one bedroom newly renovated rowhouse
# 48891      Affordable room Bushwick East Williamsburg
# 48892            Sunny Studio Historical Neighborhood
# 48893            43rd St. Time Square cozy single bed
# 48894             Trendy duplex heart Hell 's Kitchen
#
# [31362 rows x 4 columns]

# %%
# removing rows that are in not_en, with not_en_index (which was obtained in the same block of code as not_en)
temporary.drop(index = not_en_index, inplace = True)
temporary
# Out:
#                  location  sent_M1  sent_M2  \
# 0              Kensington   0.4019        1
# 1                 Midtown   0.0000        0
# 2                  Harlem   0.0000        0
# 3            Clinton Hill   0.0000        0
# 5             Murray Hill   0.0000        0
# ...                   ...      ...      ...
# 48890  Bedford-Stuyvesant   0.5859        1
# 48891            Bushwick   0.0000        0
# 48892              Harlem   0.4215        1
# 48893      Hell's Kitchen   0.0000        0
# 48894      Hell's Kitchen  -0.1027       -1
#
#                                                  name
# 0                           Clean quiet apt home park
# 1                               Skylit Midtown Castle
# 2                   THE VILLAGE OF HARLEM .NEW YORK !
# 3                        Cozy Entire Floor Brownstone
# 5           Large Cozy 1 BR Apartment In Midtown East
# ...                                               ...
# 48890   Charming one bedroom newly renovated rowhouse
# 48891      Affordable room Bushwick East Williamsburg
# 48892            Sunny Studio Historical Neighborhood
# 48893            43rd St. Time Square cozy single bed
# 48894             Trendy duplex heart Hell 's Kitchen
#
# [29617 rows x 4 columns]

# %%
neighborhood_sent = temporary.groupby(['location']).mean()
neighborhood_sent
# Out:
#                   sent_M1   sent_M2
# location
# Allerton         0.272953  0.500000
# Arden Heights    0.048133  0.000000
# Arrochar         0.123245  0.250000
# Arverne          0.211664  0.375000
# Astoria          0.259594  0.439394
# ...                   ...       ...
# Willowbrook      0.784500  1.000000
# Windsor Terrace  0.361880  0.674157
# Woodhaven        0.272691  0.507246
# Woodlawn        -0.023111  0.000000
# Woodside         0.204477  0.359756
#
# [218 rows x 2 columns]

# %%
def polarity_range(score):
    if(score >= 0.05):
        return 1
    elif(score <= -0.05):
        return -1
    return 0


# obtaining our different sentiment scores
nhood_sent_M1 = neighborhood_sent['sent_M1']
nhood_sent_M2 = neighborhood_sent['sent_M2']

# applying our function to sent_M2 to turn it into -1, 0 and +1 only
nhood_sent_M2 = nhood_sent_M2.apply(polarity_range)

# %%
nhood_sent_M1
# Out:
# location
# Allerton           0.272953
# Arden Heights      0.048133
# Arrochar           0.123245
# Arverne            0.211664
# Astoria            0.259594
#                      ...
# Willowbrook        0.784500
# Windsor Terrace    0.361880
# Woodhaven          0.272691
# Woodlawn          -0.023111
# Woodside           0.204477
# Name: sent_M1, Length: 218, dtype: float64

# %% [markdown]
# Now let's combine everything we have

# %% [markdown]
# Now subbing these averages back into our original Series of sentiment scores

# %%
sent_m1 = sentiment_M1.copy()
sent_m2 = sentiment_M2.copy()

for index in not_en_index:
    sent_m1[index] = nhood_sent_M1[df['neighbourhood'][index]]
    sent_m2[index] = nhood_sent_M2[df['neighbourhood'][index]]

# %% [markdown]
# Now that we have all the required features, we can put our final dataset together and begin creating our models

# %% [markdown]
# <h3> Preparing Data

# %% [markdown]
# Let's take another look at our dataframe

# %%
df.head()
# Out:
#                                         name neighbourhood_group  \
# 0         Clean & quiet apt home by the park            Brooklyn
# 1                      Skylit Midtown Castle           Manhattan
# 2        THE VILLAGE OF HARLEM....NEW YORK !           Manhattan
# 3            Cozy Entire Floor of Brownstone            Brooklyn
# 5  Large Cozy 1 BR Apartment In Midtown East           Manhattan
#
#   neighbourhood        room_type  price  minimum_nights  number_of_reviews  \
# 0    Kensington     Private room    149               1                  9
# 1       Midtown  Entire home/apt    225               1                 45
# 2        Harlem     Private room    150               3                  0
# 3  Clinton Hill  Entire home/apt     89               1                270
# 5   Murray Hill  Entire home/apt    200               3                 74
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2               0.00                               1               365
# 3               4.64                               1               194
# 5               0.59                               1               129

# %% [markdown]
# Number_of_reviews and reviews_per_month does not give us much help since we don't know if the reviews were positive or negative. Because it is so ambiguous, we can drop these 2 columns

# %%
df.drop(columns = ['number_of_reviews',	'reviews_per_month'], inplace = True)
df.head()
# Out:
#                                         name neighbourhood_group  \
# 0         Clean & quiet apt home by the park            Brooklyn
# 1                      Skylit Midtown Castle           Manhattan
# 2        THE VILLAGE OF HARLEM....NEW YORK !           Manhattan
# 3            Cozy Entire Floor of Brownstone            Brooklyn
# 5  Large Cozy 1 BR Apartment In Midtown East           Manhattan
#
#   neighbourhood        room_type  price  minimum_nights  \
# 0    Kensington     Private room    149               1
# 1       Midtown  Entire home/apt    225               1
# 2        Harlem     Private room    150               3
# 3  Clinton Hill  Entire home/apt     89               1
# 5   Murray Hill  Entire home/apt    200               3
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 5                               1               129

# %% [markdown]
# Dropping off all of our features that are not used or have been transformed.

# %%
df.drop(columns = ['name', 'neighbourhood_group', 'neighbourhood', 'room_type'], inplace = True)
df.head()
# Out:
#    price  minimum_nights  calculated_host_listings_count  availability_365
# 0    149               1                               6               365
# 1    225               1                               2               355
# 2    150               3                               1               365
# 3     89               1                               1               194
# 5    200               3                               1               129

# %% [markdown]
# Extracting our target label

# %%
# creating a copy of df for later
df_copy = df.copy()
#################################
y = df['price']
df.drop(columns = ['price'], inplace = True)

# %% [markdown]
# Now adding our features from before. Two dataframes are created to account for both methods used to calculate sentiment

# %%
df_sent_m1 = df.copy()
df_sent_m2 = df.copy()

df_sent_m1['sentiment'] = sent_m1
df_sent_m2['sentiment'] = sent_m2


# adding onto our copy of df
df_copy['sent_m1'] = sent_m1
df_copy['sent_m2'] = sent_m2

# %% [markdown]
# Let's take a quick look at the correlation coefficient that price has with every other feature

# %%
corr_matrix_m1 = df_copy.corr()
corr_matrix_m1["price"].sort_values(ascending = False)
# Out:
# price                             1.000000
# availability_365                  0.074509
# calculated_host_listings_count    0.060828
# minimum_nights                    0.039449
# sent_m1                          -0.024784
# sent_m2                          -0.027488
# Name: price, dtype: float64

# %% [markdown]
# So there is a very low correlation coefficient with price and our other features (reaching even negative values for our sentiment values. This can indicate one of 2 things:
# 1. there is little to no relationship between price and the other features
# 2. the relationship between the other features is nonlinear to price since correlation coefficient is only a measure of linear relationship

# %%
object_cols
# Out:
# <31362x226 sparse matrix of type '<class 'numpy.float64'>'
# 	with 94086 stored elements in Compressed Sparse Row format>

# %%
# we will change df_sent_m1 and _m2 into sparse matrices as this data type get processed better
from scipy import sparse
#from scipy.sparse import hstack

X_m1 = sparse.hstack([object_cols, sparse.csr_matrix(df_sent_m1.to_numpy())])
X_m2 = sparse.hstack([object_cols, sparse.csr_matrix(df_sent_m2.to_numpy())])

# %% [markdown]
# <h4> Train/Test

# %% [markdown]
# Now splitting the data by using train/test

# %%
from sklearn.model_selection import train_test_split
X_train_m1, X_test_m1, y_train_m1, y_test_m1 = train_test_split(X_m1, y, test_size = 0.2, random_state = 42)
X_train_m2, X_test_m2, y_train_m2, y_test_m2 = train_test_split(X_m2, y, test_size = 0.2, random_state = 42)

y_train_m1 = y_train_m1.tolist()
y_train_m2 = y_train_m2.tolist()
y_test_m1 = y_test_m1.tolist()
y_test_m2 = y_test_m2.tolist()

# %% [markdown]
# To obtain more accurate results, normalization will be applied to the appropiate columns

# %%
temp_train_m1 = X_train_m1[:, X_train_m1.shape[1]-4:].toarray()
temp_train_m2 = X_train_m2[:, X_train_m2.shape[1]-4: X_test_m2.shape[1]-1].toarray()

temp_test_m1 = X_test_m1[:, X_test_m1.shape[1]-4:].toarray()
temp_test_m2 = X_test_m2[:, X_test_m2.shape[1]-4: X_test_m2.shape[1]-1].toarray()

from sklearn.preprocessing import StandardScaler
scaler_m1 = StandardScaler().fit(temp_train_m1)
scaler_m2 = StandardScaler().fit(temp_train_m2)

temp_train_m1 = scaler_m1.transform(temp_train_m1)
temp_train_m2 = scaler_m2.transform(temp_train_m2)

temp_test_m1 = scaler_m1.transform(temp_test_m1)
temp_test_m2 = scaler_m2.transform(temp_test_m2)

# %%
X_train_m1[:,X_train_m1.shape[1]-4:] = sparse.csr_matrix(temp_train_m1)
X_train_m2[:,X_train_m2.shape[1]-4: X_test_m2.shape[1]-1] = sparse.csr_matrix(temp_train_m2)

X_test_m1[:,X_test_m1.shape[1]-4: ] = sparse.csr_matrix(temp_test_m1)
X_test_m2[:,X_test_m2.shape[1]-4: X_test_m2.shape[1]-1] = sparse.csr_matrix(temp_test_m2)
# Out:
# C:\Users\Daniel\anaconda3\lib\site-packages\scipy\sparse\_index.py:118: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)

# %% [markdown]
# Now that we have prepared our train and test data, we can begin to create models

# %% [markdown]
# <h3> Model Building

# %% [markdown]
# The models that we will try are:
# 1. SVM
# 2. Lasso Regression
# 3. Ridge Regression
# 4. Linear Regression
# 5. Random Forests
# 6. Neural network
#
# Cross validation with stratified k fold will be used to determine the most appropiate model.

# %%
from sklearn.svm import SVR
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from keras.models import Sequential
from keras.layers import Dense
from keras import regularizers
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold
from keras.initializers import RandomNormal

#### FOR NEURAL NETWORK ####
initializer = RandomNormal(mean=0., stddev=1.)

def neural_net():
    model = Sequential()
    model.add(Dense(int(2/3 * X_test_m1.shape[1]), kernel_initializer = initializer, activation = 'relu', input_dim = X_test_m1.shape[1]))
    model.add(Dense(int(4/9 * X_test_m1.shape[1]), kernel_initializer = initializer, activation = 'relu'))
    model.add(Dense(1, kernel_initializer = 'normal', activation = 'relu'))
    model.compile(optimizer = 'SGD', loss = 'mse', metrics = ['mae'])
    return model
############################    

models = []
models += [['SVM', SVR(kernel = 'linear')]]
models += [['Lasso', Lasso(alpha = 0.9, normalize = False, selection = 'cyclic')]]
models += [['Ridge', Ridge(alpha = 0.9, normalize = False, solver = 'auto')]]
models += [['Linear', LinearRegression(normalize = False)]]
models += [['Random Forests', RandomForestClassifier(n_estimators = 100, max_features = X_test_m1.shape[1], random_state = 42, max_depth = 9)]]

# for the k fold cross validation
kfold = KFold(n_splits = 10, random_state = 1, shuffle = True)

# %% [markdown]
# Performing cross validation

# %% [markdown]
# <h4> Method 1

# %%
from sklearn.model_selection import cross_val_score

result_m1 =[]
names = []

for name, model in models:
    cv_score = -1 * cross_val_score(model, X_train_m1, y_train_m1, cv = kfold, scoring = 'neg_mean_absolute_error')
    result_m1 +=[cv_score]
    names += [name]
    print('%s: %f (%f)' % (name,cv_score.mean(), cv_score.std()))
# Out:
# SVM: 66.049805 (4.989095)
# Lasso: 78.135708 (4.323603)
# Ridge: 77.659568 (4.610512)
# Linear: 77.758034 (4.615779)
# Random Forests: 66.762903 (5.114323)

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

estimator = KerasRegressor(build_fn = neural_net, epochs = 1000, batch_size = 2000, verbose=0)
results = -1 * cross_val_score(estimator, X_train_m1, y_train_m1, cv = kfold, scoring = 'neg_mean_absolute_error')
print("Neural net: %f (%f) MSE" % (results.mean(), results.std()))
# Out:
# Neural net: 160.911656 (5.378138) MSE

# %% [markdown]
# <h4> Method 2

# %%
result_m2 =[]
names = []

for name, model in models:
    cv_score = -1 * cross_val_score(model, X_train_m2, y_train_m2, cv = kfold, scoring = 'neg_mean_absolute_error')
    result_m2 +=[cv_score]
    names += [name]
    print('%s: %f (%f)' % (name,cv_score.mean(), cv_score.std()))
# Out:
# SVM: 66.046219 (4.999490)
# Lasso: 78.114655 (4.341362)
# Ridge: 77.638274 (4.622443)
# Linear: 77.740965 (4.629480)
# Random Forests: 66.761026 (5.112784)

# %%
estimator = KerasRegressor(build_fn = neural_net, epochs = 1000, batch_size = 2000, verbose=0)
results = -1 * cross_val_score(estimator, X_train_m2, y_train_m2, cv = kfold, scoring = 'neg_mean_absolute_error')
print("Neural net: %f (%f) MSE" % (results.mean(), results.std()))
# Out:
# Neural net: 160.911656 (5.378138) MSE

# %% [markdown]
# It seems that a linear SVM has the lowest mean score, and interestingly the 2nd method of using strict values of +1, 0 or -1 for the sentiment resulted in marginally better results for all models.

# %% [markdown]
# <h3> Final Evaluation

# %% [markdown]
# So our final chosen model will be a linear SVM, using the 2nd method for sentiment

# %%
model = SVR(kernel = 'linear').fit(X_train_m2, y_train_m2)

# obtaining predictions
predictions = model.predict(X_test_m2)

# %% [markdown]
# Evaluating our model

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
print("Final mean squared error: %f      R^2 value: %f" %(mean_absolute_error(y_test_m2, predictions), r2_score(y_test_m2, predictions)))
# Out:
# Final mean squared error: 70.950375      R^2 value: 0.062358

# %% [markdown]
# This is a very high MSE and has a very poor fit to our data.
#
# **NOTE**: To be quite honest, tweaking hyperparameters is something that I am still not entirely comfortable doing, so it will be skipped here for now. Will pick this notebook back up once I learn more.
